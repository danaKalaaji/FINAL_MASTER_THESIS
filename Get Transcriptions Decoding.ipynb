# %%
import requests,json,base64
import pandas as pd
import os
from segment_service import align_texts
import time
import librosa
import torch
from transformers import Wav2Vec2ForCTC, Wav2Vec2ProcessorWithLM, Wav2Vec2Processor

# %% [markdown]
# # The paths

# %%
service_address_local = "http://localhost:8070/segment"
service_address_server = "https://19af-130-60-24-13.ngrok-free.app/segment"   ### This service address is fixed. Nianlong set it up on a server.

recordings_folder_path = r"../Intervention_T1_data/recordings/deco_trials/FR_deco/FR_deco"
decoding_trial_path = r"../Intervention_T1_data/ground_truth_transcribed/Decoding/deco_test_ground_truth_FR_T1_first_coder_.csv"
phon_del_trial_path = r"../Intervention_T1_data/ground_truth_transcribed/PhonDel/phonDel_test_ground_truth_ALL_T1_first_coder.csv"
path_filters = None

# %% [markdown]
# # Get the ASR Transcription and Alignment for all files

# %%
def fill_df(recordings_filepaths, df, service_address, json_path, asr_method, asr_response_col, process_time_col):
        
    for audio_path in recordings_filepaths:
        # Get the reference text and language for the audio file
        audio_file_path = os.path.basename(audio_path)
        if audio_file_path in df["filename"].values: 
            # add condition that we only do for rows where df[df[asr_response_col].apply(lambda x: x["transcription"]["words"] == [])]
            #if list(df.loc[df["filename"] == audio_file_path][asr_response_col])[0]["transcription"]["words"] == []:

                reference_text = list(df.loc[df["filename"] == audio_file_path]["reference_text"])[0] 
                language = list(df.loc[df["filename"] == audio_file_path]["language"])[0]
                
                # Call the segment service with the audio file and reference text
                print("Processing file: ", audio_file_path)
                time_start = time.time()
                response_asr = call_segment_service(service_address, audio_path, reference_text, language, asr_method)
                time_end = time.time()
                print("ASR response: ", response_asr)
                # Get the human transcription and remove annotations
                human_transcription = list(df.loc[df["filename"] == audio_file_path]["words_human_transcription"])[0]

                # Update the df with the ASR responses and human alignments
                df.loc[df["filename"] == audio_file_path, "human_alignment"] = [{"alignment": align_texts(reference_text, human_transcription)}]
                df.loc[df["filename"] == audio_file_path, asr_response_col] = [response_asr]
                df.loc[df["filename"] == audio_file_path, process_time_col] = [time_end - time_start]

                # Save the updated df to a JSON file
                df.to_json(json_path, orient='records')

                
    return df

# %%
def wav2vec2(audio, sr, 
            processor, 
            model, 
            reference_text = None, 
            pool = None, 
            num_processes= None,
            beam_width= None,
            beam_prune_logp = None,
            token_min_logp = None,
            hotwords = None,
            hotword_weight = None,
            alpha = None,
            beta = None,
            unk_score_offset = None,
            lm_score_boundary = None,
            output_word_offsets= False,
            output_char_offsets= False,
            n_best = 1,
            with_lm = False,
            phoneme = False,
            noise_reduction = False,
            start_offset = None,
            end_offset = None,
            slow_down = False):
    
    
    start_offset = start_offset if start_offset else 0
    end_offset = end_offset if end_offset else len(audio)/sr

    audio = audio[int( start_offset * sr ):int( end_offset * sr )]

    if slow_down:
        audio = librosa.effects.time_stretch(audio, rate = 1.1)
        
    if noise_reduction:
        audio = nr.reduce_noise(audio, sr, prop_decrease=1)
        
    inputs = processor(audio, sampling_rate=sr, return_tensors="pt", padding=True)

    #inputs = inputs.to('cuda')

    with torch.no_grad():
        logits = model(**inputs).logits.cpu()
    
    if phoneme:
        predicted_ids = torch.argmax(logits, dim=-1)
        transcription_dict = processor.decode(predicted_ids[0], output_char_offsets = output_char_offsets)
        # compute `time_offset` in seconds as product of downsampling ratio and sampling_rate
        '''	
        if output_char_offsets == True:
            time_offset = model.config.inputs_to_logits_ratio / processor.feature_extractor.sampling_rate
            for i in range(len(transcription_dict['char_offsets'])): 
                transcription_dict['char_offsets'][i]["start_offset"] = round(transcription_dict['char_offsets'][i]["start_offset"] * time_offset, 2)
                transcription_dict['char_offsets'][i]["end_offset"] = round(transcription_dict['char_offsets'][i]["end_offset"] * time_offset, 2)
        '''
        transcription_dict = {"text": transcription_dict['text'].lower(), 
                              "char_offsets": transcription_dict['char_offsets'] if output_char_offsets else None }
        alignment_result = align_texts(reference_text, transcription_dict['text'].lower()) if reference_text else None
        result = {
            "transcription": transcription_dict,
            "alignment": alignment_result
        } if reference_text else transcription_dict

        transcriptions = [result]
    else:
        if not with_lm:
            predicted_ids = torch.argmax(logits, dim=-1)
            transcription_text = processor.decode(predicted_ids[0]).lower()
            transcription_dict = {"text": transcription_text}
            alignment_result = align_texts(reference_text, transcription_text) if reference_text else None
            result = {
                "transcription": transcription_dict,
                "alignment": alignment_result
            } if reference_text else transcription_dict

            transcriptions = [result]
        else:
            transcription = processor.batch_decode(logits.numpy(), output_word_offsets=output_word_offsets, 
                                                n_best =n_best, pool=pool, num_processes=num_processes, 
                                                beam_width=beam_width, beam_prune_logp=beam_prune_logp,
                                                token_min_logp=token_min_logp, hotwords=hotwords,
                                                hotword_weight=hotword_weight, alpha=alpha, beta=beta,
                                                unk_score_offset=unk_score_offset, lm_score_boundary=lm_score_boundary)
                                                
            # if only one transcription is returned, convert it to a list for consistency
            if n_best == 1 or not with_lm:
                transcription.text = [transcription.text]
                transcription.logit_score = [transcription.logit_score] if with_lm else None
                transcription.lm_score = [transcription.lm_score] if with_lm else None
                transcription.word_offsets = [transcription.word_offsets] if output_word_offsets else None

            # compute `time_offset` in seconds as product of downsampling ratio and sampling_rate
            if output_word_offsets == True:
                time_offset = model.config.inputs_to_logits_ratio / processor.feature_extractor.sampling_rate
                for i in range(len(transcription.word_offsets[0])): 
                    for dict in transcription.word_offsets[0][i]:
                        dict["start_offset"] = round(dict["start_offset"] * time_offset, 2)
                        dict["end_offset"] = round(dict["end_offset"] * time_offset, 2)

            
            # change output format to dictionary
            transcriptions = []
            for i in range(len(transcription.text[0])):
                transcription_dict = {"text": transcription.text[0][i],
                                        "logit_score": transcription.logit_score[0][i],
                                        "lm_score": transcription.lm_score[0][i] if with_lm else None,
                                        "word_offsets": transcription.word_offsets[0][i] if output_word_offsets else None
                                    }
                alignment_result = align_texts(reference_text, transcription.text[0][i]) if reference_text else None

                result = {
                    "transcription": transcription_dict,
                    "alignment": alignment_result
                } if reference_text else transcription_dict
                
                transcriptions.append(result)

    return transcriptions, logits

# %%
def fill_df_wav2vec2(df, json_path, asr_response_col, process_time_col, model_ID_list, 
            pool = None, num_processes= None, beam_width= None, beam_prune_logp = None,
            token_min_logp = None, hotwords = False, hotword_weight = None,
            alpha = None, beta = None, unk_score_offset = None, lm_score_boundary = None,
            output_word_offsets= False, n_best = 1, with_lm = False):
    
    models = [Wav2Vec2ForCTC.from_pretrained(id) for id in model_ID_list]
    if with_lm:
        processors = [Wav2Vec2ProcessorWithLM.from_pretrained(id) for id in model_ID_list]
    else:
        processors = [Wav2Vec2Processor.from_pretrained(id) for id in model_ID_list]

    for idx, row in df.iterrows():
        # Get the reference text and language for the audio file
        filename = row["filename"]
        reference_text = row["reference_text"]
        language = row["language"]
        filepath = row["filepath"]
        
        if language == "fr":
            processor = processors[0]
            model = models[0]
        elif language == "it":
            processor = processors[1]
            model = models[1]

        # Call the segment service with the audio file and reference text
        print("Processing file: ", filename)
        time_start = time.time()
        hotwords_list = reference_text.split(' ') if hotwords else None
        audio, sr = librosa.load(filepath, sr=16000)
        response_asr, logits = wav2vec2(audio=audio, sr=sr, processor=processor, model=model, 
                                        reference_text=reference_text, hotwords=hotwords_list ,
                                        hotword_weight= hotword_weight, alpha=alpha, beta=beta, 
                                        unk_score_offset=unk_score_offset, lm_score_boundary=lm_score_boundary, 
                                        output_word_offsets = output_word_offsets, n_best = n_best, with_lm = with_lm)
        time_end = time.time()
        print("ASR response: ", response_asr)
        # Convert the response to a json format
        response_asr = json.dumps(response_asr)

        # Get the human transcription and remove annotations
        human_transcription = row["words_human_transcription"]

        # Update the df with the ASR responses and human alignments
        df.loc[df["filename"] == filename, "human_alignment"] = [{"alignment": align_texts(reference_text, human_transcription)}]
        df.loc[df["filename"] == filename, asr_response_col] = [response_asr]
        df.loc[df["filename"] == filename, process_time_col] = [time_end - time_start]

        # Save the updated df to a JSON file
        df.to_json(json_path, orient='records')
    return df

# %%
df = pd.read_json(r'dfs/deco/Intervention_df_cleaned_deco.json')
df_1 = pd.read_json(r"dfs/deco/Intervention_df_1_deco.json")
df_2 = pd.read_json(r"dfs/deco/Intervention_df_2_deco.json")
df_3 = pd.read_json(r"dfs/deco/Intervention_df_3_deco.json")
df_4 = pd.read_json(r"dfs/deco/Intervention_df_4_deco.json")
df_5 = pd.read_json(r"dfs/deco/Intervention_df_5_deco.json")
df_list = [df_1, df_2, df_3, df_4, df_5]

n_best = 1
########################################

# WhipserX, v2v2 XLS and VOX models as they are
whisperX_json_path = "df_results/intervention/decoding_whisperX.json"
wav2vec2_vox_json_path = "df_results/intervention/decoding_wav2vec2_vox.json"
wav2vec2_xls_json_path = "df_results/intervention/decoding_wav2vec2_xls.json"

# v2v2 XLS models with no LM (greedy vs beam search)
wav2vec2_xls_json_path_no_LM = "df_results/intervention/decoding_wav2vec2_xls_no_LM.json"
wav2vec2_xls_json_path_no_LM_beam = "df_results/intervention/decoding_wav2vec2_xls_no_LM_beam.json"

# v2v2 XLS models with LM (Ref only vs Human Transcription) 
lm_Ref_wav2vec2_xls_json_path = "df_results/intervention/decoding_wav2vec2_xls_lm_Ref.json"
hotwords_wav2vec2_xls_json_path = "df_results/intervention/decoding_wav2vec2_xls_Hotwords.json"
hotwords_lm_xls_json_path = "df_results/intervention/decoding_wav2vec2_xls_lm_Hotwords.json"

wav2vec2_LM_models = [
    "Dandan0K/Intervention-xls-FR-Hum-no-df1", "Dandan0K/Intervention-xls-FR-Hum-no-df1-vowels", 
    "Dandan0K/Intervention-xls-FR-Hum-no-df2", "Dandan0K/Intervention-xls-FR-Hum-no-df2-vowels", 
    "Dandan0K/Intervention-xls-FR-Hum-no-df3", "Dandan0K/Intervention-xls-FR-Hum-no-df3-vowels",
    "Dandan0K/Intervention-xls-FR-Hum-no-df4", "Dandan0K/Intervention-xls-FR-Hum-no-df4-vowels", 
    "Dandan0K/Intervention-xls-FR-Hum-no-df5", "Dandan0K/Intervention-xls-FR-Hum-no-df5-vowels"
    ]
wav2vec2_LM_json_paths = [
    r"df_results\intervention\decoding_wav2vec2_df_1_xls.json",
    r"df_results\intervention\decoding_wav2vec2_df_1_xls_vowels.json"
    r"df_results\intervention\decoding_wav2vec2_df_2_xls.json",
    r"df_results\intervention\decoding_wav2vec2_df_2_xls_vowels.json",
    r"df_results\intervention\decoding_wav2vec2_df_3_xls.json",
    r"df_results\intervention\decoding_wav2vec2_df_3_xls_vowels.json",
    r"df_results\intervention\decoding_wav2vec2_df_4_xls.json",
    r"df_results\intervention\decoding_wav2vec2_df_4_xls_vowels.json",
    r"df_results\intervention\decoding_wav2vec2_df_5_xls.json",
    r"df_results\intervention\decoding_wav2vec2_df_5_xls_vowels.json"
]   

wav2vec2_LM_models = [
    "Dandan0K/Intervention-xls-FR-Hum-no-df1", 
    "Dandan0K/Intervention-xls-FR-Hum-no-df1-vowels"
    ]
wav2vec2_LM_json_paths = [
    r"df_results\intervention\decoding_wav2vec2_df_1_xls.json",
    r"df_results\intervention\decoding_wav2vec2_df_1_xls_vowels.json"
] 

########################################
# v2v2 VOX models with different ratio of male/female speakers in the fine-tuning data
wav2vec2_gender_json_paths = [
    # vox models
    "df_results/intervention/gender/decoding_wav2vec2_vox_M10F0.json",
    "df_results/intervention/gender/decoding_wav2vec2_vox_M8F2.json",
    "df_results/intervention/gender/decoding_wav2vec2_vox_M5F5.json",
    "df_results/intervention/gender/decoding_wav2vec2_vox_M2F2.json",
    "df_results/intervention/gender/decoding_wav2vec2_vox_M0F10.json",
    # xls models
    "df_results/intervention/gender/decoding_wav2vec2_xls_M10F0.json",
    "df_results/intervention/gender/decoding_wav2vec2_xls_M8F2.json",
    "df_results/intervention/gender/decoding_wav2vec2_xls_M5F5.json",
    "df_results/intervention/gender/decoding_wav2vec2_xls_M2F2.json",
    "df_results/intervention/gender/decoding_wav2vec2_xls_M0F10.json"
]
wav2vec2_gender_models = [
    # vox models
    "jonatasgrosman/exp_w2v2r_fr_vp-100k_gender_male-10_female-0_s714",
    "jonatasgrosman/exp_w2v2r_fr_vp-100k_gender_male-8_female-2_s911",
    "jonatasgrosman/exp_w2v2r_fr_vp-100k_gender_male-5_female-5_s722",
    "jonatasgrosman/exp_w2v2r_fr_vp-100k_gender_male-2_female-8_s473",
    "jonatasgrosman/exp_w2v2r_fr_vp-100k_gender_male-0_female-10_s934",
    # xls models
    "jonatasgrosman/exp_w2v2r_fr_xls-r_gender_male-10_female-0_s825",
    "jonatasgrosman/exp_w2v2r_fr_xls-r_gender_male-8_female-2_s755",
    "jonatasgrosman/exp_w2v2r_fr_xls-r_gender_male-5_female-5_s916",
    "jonatasgrosman/exp_w2v2r_fr_xls-r_gender_male-2_female-8_s886",
    "jonatasgrosman/exp_w2v2r_fr_xls-r_gender_male-0_female-10_s895"
]

# %%
"""
df_asr = df
df_wav2vec2_xls_no_LM =  fill_df_wav2vec2(
                            df = df_asr,
                            json_path = wav2vec2_xls_json_path_no_LM,
                            asr_response_col = 'asr_response',
                            process_time_col = 'process_time',
                            model_ID_list = ["Dandan0K/Intervention-xls-FR-no-LM"],
                        )  
print("Done with wav2vec2_xls_no_LM")

df_asr = df
df_wav2vec2_xls_no_LM_beam=  fill_df_wav2vec2(
                            df = df_asr,
                            json_path = wav2vec2_xls_json_path_no_LM_beam,
                            asr_response_col = 'asr_response',
                            process_time_col = 'process_time',
                            model_ID_list = ["Dandan0K/Intervention-xls-FR-no-LM"],
                            n_best = n_best,
                            with_lm = True,
                        )  
print("Done with df_wav2vec2_xls_no_LM_beam")



for index, (wav2vec2_model, json_path) in enumerate(zip(wav2vec2_LM_models, wav2vec2_LM_json_paths)):
    print(f"Processing model: {wav2vec2_model}")
    print(f"JSON path: {json_path}")
    df_wav2vec2 = fill_df_wav2vec2(
                            df=df_list[index // 2],  # Assuming each model corresponds to every two dataframes
                            json_path=json_path,
                            asr_response_col='asr_response',
                            process_time_col='process_time',
                            model_ID_list=[wav2vec2_model],
                            n_best=n_best,
                            with_lm=True
                        )
    print(f"Done with model: {wav2vec2_model}")

    
df_asr = df
df_whisperx =  fill_df(
                       df = df_asr, 
                       service_address = service_address_server, 
                       json_path = whisperX_json_path, 
                       asr_method = 'whisperx', 
                       asr_response_col = 'asr_response',
                       process_time_col = 'process_time')
print("Done with WhisperX") 

df_asr = df
df_wav2vec2_vox =  fill_df_wav2vec2(
                            df = df_asr,
                            json_path = wav2vec2_vox_json_path,
                            asr_response_col = 'asr_response',
                            process_time_col = 'process_time',
                            model_ID_list = ["jonatasgrosman/exp_w2v2t_fr_vp-100k_s973", 
                                           "jonatasgrosman/exp_w2v2t_it_vp-100k_s449"],
                            n_best = n_best,
                        )  
print("Done with wav2vec2_vox")


df_asr = df
df_wav2vec2_xls =  fill_df_wav2vec2(
                        df = df_asr, 
                        json_path = wav2vec2_xls_json_path, 
                        asr_response_col = 'asr_response',
                        process_time_col = 'process_time',
                        model_ID_list = ["jonatasgrosman/wav2vec2-xls-r-1b-french", 
                                        "jonatasgrosman/wav2vec2-xls-r-1b-italian"],
                        n_best = n_best,
                        with_lm = True)
print("Done with wav2vec2_xls")

for wav2vec2_model, json_path in zip(wav2vec2_gender_models, wav2vec2_gender_json_paths):
    df_asr = df
    print("Processing model: ", wav2vec2_model)
    print(" json path: ", json_path)
    df_wav2vec2 =  fill_df_wav2vec2(
                            df = df_asr,
                            json_path = json_path,
                            asr_response_col = 'asr_response',
                            process_time_col = 'process_time',
                            model_ID_list = [wav2vec2_model],
                        )  
    print("Done with model: ", wav2vec2_model)
"""
# Out:
# '\ndf_asr = df\ndf_whisperx =  fill_df(\n                       df = df_asr, \n                       service_address = service_address_server, \n                       json_path = whisperX_json_path, \n                       asr_method = \'whisperx\', \n                       asr_response_col = \'asr_response\',\n                       process_time_col = \'process_time\')\nprint("Done with WhisperX") \n\ndf_asr = df\ndf_wav2vec2_vox =  fill_df_wav2vec2(\n                            df = df_asr,\n                            json_path = wav2vec2_vox_json_path,\n                            asr_response_col = \'asr_response\',\n                            process_time_col = \'process_time\',\n                            model_ID_list = ["jonatasgrosman/exp_w2v2t_fr_vp-100k_s973", \n                                           "jonatasgrosman/exp_w2v2t_it_vp-100k_s449"],\n                            n_best = n_best,\n                        )  \nprint("Done with wav2vec2_vox")\n\n\ndf_asr = df\ndf_wav2vec2_xls =  fill_df_wav2vec2(\n                        df = df_asr, \n                        json_path = wav2vec2_xls_json_path, \n                        asr_response_col = \'asr_response\',\n                        process_time_col = \'process_time\',\n                        model_ID_list = ["jonatasgrosman/wav2vec2-xls-r-1b-french", \n                                        "jonatasgrosman/wav2vec2-xls-r-1b-italian"],\n                        n_best = n_best,\n                        with_lm = True)\nprint("Done with wav2vec2_xls")\n\nfor wav2vec2_model, json_path in zip(wav2vec2_gender_models, wav2vec2_gender_json_paths):\n    df_asr = df\n    print("Processing model: ", wav2vec2_model)\n    print(" json path: ", json_path)\n    df_wav2vec2 =  fill_df_wav2vec2(\n                            df = df_asr,\n                            json_path = json_path,\n                            asr_response_col = \'asr_response\',\n                            process_time_col = \'process_time\',\n                            model_ID_list = [wav2vec2_model],\n                        )  \n    print("Done with model: ", wav2vec2_model)\n'

# %%
df_asr = df
df_wav2vec2_xls_no_LM =  fill_df_wav2vec2(
                            df = df_asr,
                            json_path = wav2vec2_xls_json_path_no_LM,
                            asr_response_col = 'asr_response',
                            process_time_col = 'process_time',
                            model_ID_list = ["Dandan0K/Intervention-xls-FR-no-LM"],
                        )  
print("Done with wav2vec2_xls_no_LM")

df_asr = df
df_wav2vec2_xls_hotwords_lm =  fill_df_wav2vec2(
                            df = df_asr,
                            json_path = hotwords_lm_xls_json_path,
                            asr_response_col = 'asr_response',
                            process_time_col = 'process_time',
                            model_ID_list = ["Dandan0K/Intervention-xls-FR-Ref"],
                            n_best = n_best,
                            with_lm = True,
                            hotwords= True
                        )  
print("Done with df_wav2vec2_xls_hotwords_lm")
	

df_asr = df
df_wav2vec2_xls_hotwords =  fill_df_wav2vec2(
                            df = df_asr,
                            json_path = hotwords_wav2vec2_xls_json_path,
                            asr_response_col = 'asr_response',
                            process_time_col = 'process_time',
                            model_ID_list = ["Dandan0K/Intervention-xls-FR-no-LM"],
                            n_best = n_best,
                            with_lm = True,
                            hotwords= True
                        )  
print("Done with df_wav2vec2_xls_hotwords")

# Change alpha and beta values, change unk_score

# %%
df_asr = pd.read_json('dfs/deco/Intervention_Decoding_removed_df.json')
print(len(df_asr))
df_wav2vec2_Ref_rem=  fill_df_wav2vec2(
                            df = df_asr,
                            json_path = "df_results/intervention/decoding_wav2vec2_xls_lm_Ref_del.json",
                            asr_response_col = 'asr_response',
                            process_time_col = 'process_time',
                            model_ID_list = ["Dandan0K/Intervention-xls-FR-Ref"],
                            n_best = n_best,
                            with_lm = True,
                        )  
print("Done with df_wav2vec2_xls_no_LM_beam")
# Out:
# 83
# /home/hnp_vr/miniconda3/envs/asr/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at Dandan0K/Intervention-xls-FR-Ref were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at Dandan0K/Intervention-xls-FR-Ref and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Only 218 unigrams passed as vocabulary. Is this small or artificial data?
# Processing file:  3103_edugame2023_0828b44e3f534a3eb509622760a0e1d2_08daac6429824018974fa150e351a7c5.wav
# ASR response:  [{'transcription': {'text': 'prumeu chambre demande si-tu citis le crangrand freumevelau lieux hôtel crodon chanson', 'logit_score': -65.54761182875558, 'lm_score': -178.8191719352602, 'word_offsets': None}, 'alignment': [('haie', None, 'deletion'), ('brume', 'prumeu', 'substitution'), ('chambre', 'chambre', 'match'), ('demande', 'demande', 'match'), (None, 'si', 'insertion'), (None, 'tu', 'insertion'), (None, 'citis', 'insertion'), ('style', 'le', 'substitution'), ('crâne', 'crangrand', 'substitution'), ('fureur', 'freumevelau', 'substitution'), ('manivelle', 'lieux', 'substitution'), ('hôtel', 'hôtel', 'match'), ('cordon', 'crodon', 'substitution'), ('chanson', 'chanson', 'match'), ('pommier', None, 'deletion')]}]
# Processing file:  3110_edugame2023_98b26f17034f480a97b33384488bb831_575fcc0e5d2b421089138c4870a1387b.wav
# /tmp/ipykernel_11054/3149738309.py:48: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[19.934046983718872]' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df.loc[df["filename"] == filename, process_time_col] = [time_end - time_start]
# ASR response:  [{'transcription': {'text': 'piège femme secret finit mulserf-journa précision dix duillusion débarquement', 'logit_score': -38.12207549858078, 'lm_score': -78.54638199274268, 'word_offsets': None}, 'alignment': [('piège', 'piège', 'match'), ('femme', 'femme', 'match'), ('secret', 'secret', 'match'), ('finit', 'finit', 'match'), ('mille', None, 'deletion'), ('cerf', 'mulserf', 'substitution'), ('jardin', 'journa', 'substitution'), ('précision', 'précision', 'match'), ('dix', 'dix', 'match'), ('lieux', None, 'deletion'), ('million', 'duillusion', 'substitution'), ('débarquement', 'débarquement', 'match')]}]
# Processing file:  3119_edugame2023_5e6440930fc44670921d8a8b496bd499_1fac4df4c02140ada716303b8a4e2c12.wav
# ASR response:  [{'transcription': {'text': 'joue roi-ran toit quantsoit tout doncen soissonte', 'logit_score': -29.331292382009728, 'lm_score': -112.70962852486622, 'word_offsets': None}, 'alignment': [('rof', None, 'deletion'), ('rari', None, 'deletion'), ('tuit', None, 'deletion'), ('cutice', None, 'deletion'), ('zeux', 'joue', 'substitution'), ('bumon', 'roi', 'substitution'), ('bante', 'ran', 'substitution'), ('perné', 'toit', 'substitution'), ('loif', 'quantsoit', 'substitution'), ('bonfage', 'tout', 'substitution'), ('jeul', 'doncen', 'substitution'), ('trème', 'soissonte', 'substitution')]}]
# Processing file:  3119_edugame2023_5e6440930fc44670921d8a8b496bd499_20c031355cc748319b91ab50d7201c8a.wav
# ASR response:  [{'transcription': {'text': 'dans la toit sontse tente contrepesomdre stampejusqua', 'logit_score': -45.533858002098455, 'lm_score': -128.91219414495495, 'word_offsets': None}, 'alignment': [('bucurelle', None, 'deletion'), ('daveau', None, 'deletion'), ('ninoie', None, 'deletion'), ('trefonet', None, 'deletion'), ('tiège', None, 'deletion'), ('ronjeau', 'dans', 'substitution'), ('meuil', 'la', 'substitution'), ('trufondulence', 'toit', 'substitution'), ('hupeur', 'sontse', 'substitution'), ('mive', 'tente', 'substitution'), ('gralation', 'contrepesomdre', 'substitution'), ('turlème', 'stampejusqua', 'substitution')]}]
# Processing file:  3119_edugame2023_961f25cb239c493f8dc868646059fe60_627da4da957642ef9d1144ae4c4aa812.wav
# ASR response:  [{'transcription': {'text': 'lescartes sest sorvaes das desatetantes tente', 'logit_score': -28.984267990648487, 'lm_score': -110.78951566712372, 'word_offsets': None}, 'alignment': [('liège', None, 'deletion'), ('soeur', None, 'deletion'), ('regret', None, 'deletion'), ('fusil', None, 'deletion'), ('fils', None, 'deletion'), ('août', None, 'deletion'), ('garçon', 'lescartes', 'substitution'), ('production', 'sest', 'substitution'), ('gaz', 'sorvaes', 'substitution'), ('dieux', 'das', 'substitution'), ('tension', 'desatetantes', 'substitution'), ('déménagement', 'tente', 'substitution')]}]
# Processing file:  3119_edugame2023_961f25cb239c493f8dc868646059fe60_9591d5e9a5f9452a811d48d4395f3a57.wav
# ASR response:  [{'transcription': {'text': 'rejudonde sorpile donte donte tan', 'logit_score': -49.63339804836294, 'lm_score': -95.33020896332465, 'word_offsets': None}, 'alignment': [('raie', None, 'deletion'), ('grève', None, 'deletion'), ('timbre', None, 'deletion'), ('légende', None, 'deletion'), ('stand', None, 'deletion'), ('crête', None, 'deletion'), ('voleur', None, 'deletion'), ('mirabelle', 'rejudonde', 'substitution'), ('amour', 'sorpile', 'substitution'), ('lardon', 'donte', 'substitution'), ('saison', 'donte', 'substitution'), ('pompier', 'tan', 'substitution')]}]
# Processing file:  3119_edugame2023_961f25cb239c493f8dc868646059fe60_bd422dbdc0554417985de26a5770fdbd.wav
# ASR response:  [{'transcription': {'text': 'ouleltoi raie joun-sapde andeux tente chanson choix cou', 'logit_score': -60.16087102809239, 'lm_score': -133.60051287228606, 'word_offsets': None}, 'alignment': [('toit', None, 'deletion'), ('régal', None, 'deletion'), ('juin', 'ouleltoi', 'substitution'), ('escapade', 'raie', 'substitution'), ('navet', 'joun', 'substitution'), ('pente', 'sapde', 'substitution'), ('bandit', 'andeux', 'substitution'), ('chaleur', 'tente', 'substitution'), ('carré', 'chanson', 'substitution'), ('choix', 'choix', 'match'), ('parade', None, 'deletion'), ('fossile', 'cou', 'substitution')]}]
# Processing file:  3119_edugame2023_961f25cb239c493f8dc868646059fe60_f56a5c77a5b84723a9622cce8a6942cb.wav
# ASR response:  [{'transcription': {'text': 'lilotuche demande taennologe navet pente dansunsetard', 'logit_score': -86.75903138838754, 'lm_score': -144.55523891431108, 'word_offsets': None}, 'alignment': [('gigot', None, 'deletion'), ('duvet', None, 'deletion'), ('convalescence', None, 'deletion'), ('excitation', None, 'deletion'), ('tronc', None, 'deletion'), ('poire', None, 'deletion'), ('mouette', 'lilotuche', 'substitution'), ('menuisier', 'demande', 'substitution'), ('casier', 'taennologe', 'substitution'), ('equateur', 'navet', 'substitution'), ('orchestre', 'pente', 'substitution'), ('réclamation', 'dansunsetard', 'substitution')]}]
# Processing file:  3142_edugame2023_b5e0a9ac5743470eb758689a59610bab_72c254f0757f42c7a7fe0937b3f3a437.wav
# ASR response:  [{'transcription': {'text': 'toirégal juin escargo bante bandit chaleur carré choix parade fossile', 'logit_score': -65.0913299751061, 'lm_score': -90.23899624215018, 'word_offsets': None}, 'alignment': [('toit', None, 'deletion'), ('régal', 'toirégal', 'substitution'), ('juin', 'juin', 'match'), ('escapade', None, 'deletion'), ('navet', 'escargo', 'substitution'), ('pente', 'bante', 'substitution'), ('bandit', 'bandit', 'match'), ('chaleur', 'chaleur', 'match'), ('carré', 'carré', 'match'), ('choix', 'choix', 'match'), ('parade', 'parade', 'match'), ('fossile', 'fossile', 'match')]}]
# Processing file:  3149_edugame2023_20f14ca1e76f4491b45171d370ecb639_64ac10c2e7504def9f58a6fc694cfa88.wav
# ASR response:  [{'transcription': {'text': 'siège pacifite tuit juit aquarante cieux poire', 'logit_score': -70.35479683286513, 'lm_score': -117.92994703498218, 'word_offsets': None}, 'alignment': [('siège', 'siège', 'match'), ('coeur', None, 'deletion'), ('basket', None, 'deletion'), ('récit', None, 'deletion'), ('sept', None, 'deletion'), ('clef', 'pacifite', 'substitution'), ('gourdin', 'tuit', 'substitution'), ('tradition', 'juit', 'substitution'), ('six', 'aquarante', 'substitution'), ('cieux', 'cieux', 'match'), ('moisson', None, 'deletion'), ('département', 'poire', 'substitution')]}]
# Processing file:  3149_edugame2023_20f14ca1e76f4491b45171d370ecb639_6a2b799f094f44978097c25738128594.wav
# ASR response:  [{'transcription': {'text': 'joue juit tente mititsou', 'logit_score': -46.96919479367028, 'lm_score': -79.58113447720665, 'word_offsets': None}, 'alignment': [('écho', None, 'deletion'), ('logis', None, 'deletion'), ('intelligence', None, 'deletion'), ('opposition', None, 'deletion'), ('creux', None, 'deletion'), ('foire', None, 'deletion'), ('chouette', None, 'deletion'), ('cuisinier', None, 'deletion'), ('cellier', 'joue', 'substitution'), ('estragon', 'juit', 'substitution'), ('instruments', 'tente', 'substitution'), ('malédiction', 'mititsou', 'substitution')]}]
# Processing file:  3149_edugame2023_20f14ca1e76f4491b45171d370ecb639_842363206b27493caa4a32544a414db9.wav
# ASR response:  [{'transcription': {'text': 'chambre demande style finit ingt-dhet gra', 'logit_score': -89.03778039148895, 'lm_score': -132.24664758883983, 'word_offsets': None}, 'alignment': [('haie', None, 'deletion'), ('brume', None, 'deletion'), ('chambre', 'chambre', 'match'), ('demande', 'demande', 'match'), ('style', 'style', 'match'), ('crâne', None, 'deletion'), ('fureur', None, 'deletion'), ('manivelle', None, 'deletion'), ('hôtel', 'finit', 'substitution'), ('cordon', 'ingt', 'substitution'), ('chanson', 'dhet', 'substitution'), ('pommier', 'gra', 'substitution')]}]
# Processing file:  3155_edugame2023_1c253050f444471e96fa6ff5bcc2914b_2a4565cd327b4f509b5fb574bf74126f.wav
# ASR response:  [{'transcription': {'text': '', 'logit_score': -22.15875022118648, 'lm_score': -36.96655327415367, 'word_offsets': None}, 'alignment': [('nuit', None, 'deletion'), ('métal', None, 'deletion'), ('joue', None, 'deletion'), ('escalade', None, 'deletion'), ('valet', None, 'deletion'), ('tente', None, 'deletion'), ('jaloux', None, 'deletion'), ('couleur', None, 'deletion'), ('fossé', None, 'deletion'), ('noix', None, 'deletion'), ('balade', None, 'deletion'), ('reptile', None, 'deletion')]}]
# Processing file:  3155_edugame2023_1c253050f444471e96fa6ff5bcc2914b_8cd8a3c97e8f4eb2a70052da7142dc95.wav
# ASR response:  [{'transcription': {'text': 'invenpièces femme secret finit mille cerf jardin précision dix lieusmillions déparquements', 'logit_score': -44.784245765708945, 'lm_score': -91.93979211998143, 'word_offsets': None}, 'alignment': [('piège', 'invenpièces', 'substitution'), ('femme', 'femme', 'match'), ('secret', 'secret', 'match'), ('finit', 'finit', 'match'), ('mille', 'mille', 'match'), ('cerf', 'cerf', 'match'), ('jardin', 'jardin', 'match'), ('précision', 'précision', 'match'), ('dix', 'dix', 'match'), ('lieux', None, 'deletion'), ('million', 'lieusmillions', 'substitution'), ('débarquement', 'déparquements', 'substitution')]}]
# Processing file:  3156_edugame2023_c183500d36fd40869ec0e3971031afcc_39d285455529407caf28235d16a3b924.wav
# ASR response:  [{'transcription': {'text': 'raie raie brète', 'logit_score': -97.62655070470039, 'lm_score': -102.76638749102676, 'word_offsets': None}, 'alignment': [('digacelle', None, 'deletion'), ('pireau', None, 'deletion'), ('lisoie', None, 'deletion'), ('milvenet', None, 'deletion'), ('diège', None, 'deletion'), ('conjeau', None, 'deletion'), ('beuil', None, 'deletion'), ('brumidurence', None, 'deletion'), ('héteur', None, 'deletion'), ('tive', 'raie', 'substitution'), ('pléfation', 'raie', 'substitution'), ('sorpile', 'brète', 'substitution')]}]
# Processing file:  3158_edugame2023_9badf81b4269480d9c4886c4f7b827db_19e94b7edc08497a86797e354f8faa12.wav
# ASR response:  [{'transcription': {'text': "cela je l'ai fait toutàl'heure seulpouli ruit paroce reux lamon bente nardé duie anglage jauf trèbe", 'logit_score': -71.25282243091407, 'lm_score': -154.80085052165833, 'word_offsets': None}, 'alignment': [(None, 'cela', 'insertion'), (None, 'je', 'insertion'), (None, 'l', 'insertion'), (None, 'ai', 'insertion'), (None, 'fait', 'insertion'), (None, 'toutàl', 'insertion'), ('jol', 'heure', 'substitution'), ('puli', 'seulpouli', 'substitution'), ('ruit', 'ruit', 'match'), ('paroce', 'paroce', 'match'), ('reux', 'reux', 'match'), ('lamon', 'lamon', 'match'), ('bente', 'bente', 'match'), ('nardé', 'nardé', 'match'), ('duie', 'duie', 'match'), ('anglage', 'anglage', 'match'), ('jauf', 'jauf', 'match'), ('trèbe', 'trèbe', 'match')]}]
# Processing file:  3161_edugame2023_9889b3877b724fb0abdce7aa9c0daffc_b7b7ef370786475eb73c1d56af3358d1.wav
# ASR response:  [{'transcription': {'text': "duvqu'a convalescence excitation tronc poire mouette muettjen'arrive pas lire ce mot casier", 'logit_score': -64.72664825628162, 'lm_score': -144.1644602763795, 'word_offsets': None}, 'alignment': [('gigot', 'duvqu', 'substitution'), ('duvet', 'a', 'substitution'), ('convalescence', 'convalescence', 'match'), ('excitation', 'excitation', 'match'), ('tronc', 'tronc', 'match'), ('poire', 'poire', 'match'), ('mouette', 'mouette', 'match'), (None, 'muettjen', 'insertion'), (None, 'arrive', 'insertion'), ('menuisier', 'pas', 'substitution'), ('casier', 'lire', 'substitution'), ('equateur', 'ce', 'substitution'), ('orchestre', 'mot', 'substitution'), ('réclamation', 'casier', 'substitution')]}]
# Processing file:  3165_edugame2023_8f8318fb8c834d729db979506b45e1c9_6d812c07e7bb4762a7d5d75cf318122f.wav
# ASR response:  [{'transcription': {'text': 'lait vente', 'logit_score': -176.56300790025037, 'lm_score': -180.1642791118811, 'word_offsets': None}, 'alignment': [('gigot', None, 'deletion'), ('duvet', None, 'deletion'), ('convalescence', None, 'deletion'), ('excitation', None, 'deletion'), ('tronc', None, 'deletion'), ('poire', None, 'deletion'), ('mouette', None, 'deletion'), ('menuisier', None, 'deletion'), ('casier', None, 'deletion'), ('equateur', None, 'deletion'), ('orchestre', 'lait', 'substitution'), ('réclamation', 'vente', 'substitution')]}]
# Processing file:  3167_edugame2023_3fd5c48761fa49dd8a3deecefd6c22a9_81caf06cc4124d20a088d75d3fa14e96.wav
# ASR response:  [{'transcription': {'text': 'raie bandit', 'logit_score': -65.04199169384661, 'lm_score': -68.64381051209581, 'word_offsets': None}, 'alignment': [('suf', None, 'deletion'), ('fari', None, 'deletion'), ('juit', None, 'deletion'), ('lumèce', None, 'deletion'), ('goix', None, 'deletion'), ('munon', None, 'deletion'), ('donte', None, 'deletion'), ('tondé', None, 'deletion'), ('toir', None, 'deletion'), ('rombage', None, 'deletion'), ('jeur', 'raie', 'substitution'), ('brète', 'bandit', 'substitution')]}]
# Processing file:  3167_edugame2023_3fd5c48761fa49dd8a3deecefd6c22a9_94cc3481ddef48bc8e2cc7478a69abea.wav
# ASR response:  [{'transcription': {'text': 'toit voix duvet', 'logit_score': -67.52924311510296, 'lm_score': -85.78931180090642, 'word_offsets': None}, 'alignment': [('sidomelle', None, 'deletion'), ('tiveau', None, 'deletion'), ('firoie', None, 'deletion'), ('timpunet', None, 'deletion'), ('phème', None, 'deletion'), ('tanjeau', None, 'deletion'), ('reuil', None, 'deletion'), ('flunobirence', None, 'deletion'), ('hopeur', None, 'deletion'), ('nive', 'toit', 'substitution'), ('jorcation', 'voix', 'substitution'), ('raplème', 'duvet', 'substitution')]}]
# Processing file:  3167_edugame2023_7a48c3ff29d8451aa8d6828a324bfbf4_2092a68b390a47ce8f7aec56c5ccd97e.wav
# ASR response:  [{'transcription': {'text': 'balade valeur désir doupes', 'logit_score': -95.57226175729319, 'lm_score': -115.0993302094042, 'word_offsets': None}, 'alignment': [('baie', None, 'deletion'), ('frère', None, 'deletion'), ('nombre', None, 'deletion'), ('commande', None, 'deletion'), ('stade', None, 'deletion'), ('crêpe', 'balade', 'substitution'), ('valeur', 'valeur', 'match'), ('caravelle', None, 'deletion'), ('élève', None, 'deletion'), ('pardon', None, 'deletion'), ('pinson', 'désir', 'substitution'), ('mission', 'doupes', 'substitution')]}]
# Processing file:  3167_edugame2023_7a48c3ff29d8451aa8d6828a324bfbf4_8f4231e59de84a1fb16554ad68ef93af.wav
# ASR response:  [{'transcription': {'text': 'ohbientu vas avoir une pagesurpanpané partout pardipade ba', 'logit_score': -38.30208858368137, 'lm_score': -157.7888614880514, 'word_offsets': None}, 'alignment': [('piège', None, 'deletion'), ('femme', None, 'deletion'), ('secret', None, 'deletion'), ('finit', None, 'deletion'), ('mille', 'ohbientu', 'substitution'), ('cerf', 'vas', 'substitution'), ('jardin', 'avoir', 'substitution'), ('précision', 'une', 'substitution'), ('dix', 'pagesurpanpané', 'substitution'), ('lieux', 'partout', 'substitution'), ('million', 'pardipade', 'substitution'), ('débarquement', 'ba', 'substitution')]}]
# Processing file:  3167_edugame2023_7a48c3ff29d8451aa8d6828a324bfbf4_c9e6c3eaa22a401bbeaece3e31b51611.wav
# ASR response:  [{'transcription': {'text': 'escroc entirnu', 'logit_score': -43.54585858993048, 'lm_score': -58.66178307520852, 'word_offsets': None}, 'alignment': [('escroc', 'escroc', 'match'), ('tabac', None, 'deletion'), ('reconnaissance', None, 'deletion'), ('apparition', None, 'deletion'), ('blanc', None, 'deletion'), ('poids', None, 'deletion'), ('couette', None, 'deletion'), ('chemisier', None, 'deletion'), ('rosier', None, 'deletion'), ('écuyère', None, 'deletion'), ('catastrophe', None, 'deletion'), ('déclaration', 'entirnu', 'substitution')]}]
# Processing file:  3177_edugame2023_4e6107c4aac043c592aa870d006b95e9_93b52e98a4dd4adabbdc11f8d9bc258a.wav
# ASR response:  [{'transcription': {'text': 'principajaq saqealimle pipique dinaroniq tuit', 'logit_score': -61.58667785694337, 'lm_score': -130.30705430199325, 'word_offsets': None}, 'alignment': [('piège', None, 'deletion'), ('femme', None, 'deletion'), ('secret', None, 'deletion'), ('finit', None, 'deletion'), ('mille', None, 'deletion'), ('cerf', None, 'deletion'), ('jardin', None, 'deletion'), ('précision', 'principajaq', 'substitution'), ('dix', 'saqealimle', 'substitution'), ('lieux', 'pipique', 'substitution'), ('million', 'dinaroniq', 'substitution'), ('débarquement', 'tuit', 'substitution')]}]
# Processing file:  3179_edugame2023_0153e27eeebd45c2b3f5683581b202c4_986e8bd6954b4e0eb69d1d4d87bd572d.wav
# ASR response:  [{'transcription': {'text': 'bucurelle daveau ninoie trefonet tiège rogeomilieu parleaumicro parlelemot-là tudescends chaquefois esmois trufondiolence hupeur mive gralation', 'logit_score': -172.397394424143, 'lm_score': -260.71041081476415, 'word_offsets': None}, 'alignment': [('bucurelle', 'bucurelle', 'match'), ('daveau', 'daveau', 'match'), ('ninoie', 'ninoie', 'match'), ('trefonet', 'trefonet', 'match'), ('tiège', 'tiège', 'match'), (None, 'rogeomilieu', 'insertion'), (None, 'parleaumicro', 'insertion'), (None, 'parlelemot', 'insertion'), (None, 'là', 'insertion'), (None, 'tudescends', 'insertion'), ('ronjeau', 'chaquefois', 'substitution'), ('meuil', 'esmois', 'substitution'), ('trufondulence', 'trufondiolence', 'substitution'), ('hupeur', 'hupeur', 'match'), ('mive', 'mive', 'match'), ('gralation', 'gralation', 'match'), ('turlème', None, 'deletion')]}]
# Processing file:  3182_edugame2023_779f4e2e4e9d47e1b7c81db1db880b78_378e97c3984f4b6998f5079e82d60353.wav
# ASR response:  [{'transcription': {'text': 'lacelalipac toir lamon loloteoù jarécit', 'logit_score': -88.13269547351642, 'lm_score': -145.3412891535222, 'word_offsets': None}, 'alignment': [('escroc', None, 'deletion'), ('tabac', None, 'deletion'), ('reconnaissance', None, 'deletion'), ('apparition', None, 'deletion'), ('blanc', None, 'deletion'), ('poids', None, 'deletion'), ('couette', None, 'deletion'), ('chemisier', 'lacelalipac', 'substitution'), ('rosier', 'toir', 'substitution'), ('écuyère', 'lamon', 'substitution'), ('catastrophe', 'loloteoù', 'substitution'), ('déclaration', 'jarécit', 'substitution')]}]
# Processing file:  3182_edugame2023_779f4e2e4e9d47e1b7c81db1db880b78_853163986ff2415b926eca0f31891eaa.wav
# ASR response:  [{'transcription': {'text': 'comme sicedevait piège duie', 'logit_score': -74.70112958803192, 'lm_score': -118.82485203661236, 'word_offsets': None}, 'alignment': [('piège', None, 'deletion'), ('femme', None, 'deletion'), ('secret', None, 'deletion'), ('finit', None, 'deletion'), ('mille', None, 'deletion'), ('cerf', None, 'deletion'), ('jardin', None, 'deletion'), ('précision', None, 'deletion'), ('dix', 'comme', 'substitution'), ('lieux', 'sicedevait', 'substitution'), ('million', 'piège', 'substitution'), ('débarquement', 'duie', 'substitution')]}]
# Processing file:  3182_edugame2023_f3f5a442756a47a0895c9e12308b91b3_1e69858b467f4151ba7af03a3b78f140.wav
# ASR response:  [{'transcription': {'text': 'dededouudout autant petroptôt six donte ouioui ouioui oui et voilà', 'logit_score': -83.39327771028347, 'lm_score': -206.02622754741603, 'word_offsets': None}, 'alignment': [('sidomelle', None, 'deletion'), ('tiveau', None, 'deletion'), ('firoie', 'dededouudout', 'substitution'), ('timpunet', 'autant', 'substitution'), ('phème', 'petroptôt', 'substitution'), ('tanjeau', 'six', 'substitution'), ('reuil', 'donte', 'substitution'), ('flunobirence', 'ouioui', 'substitution'), ('hopeur', 'ouioui', 'substitution'), ('nive', 'oui', 'substitution'), ('jorcation', 'et', 'substitution'), ('raplème', 'voilà', 'substitution')]}]
# Processing file:  3182_edugame2023_f3f5a442756a47a0895c9e12308b91b3_81a3194914e64f33acb7b33429c95e6c.wav
# ASR response:  [{'transcription': {'text': 'nuit reuil donte bouprêeale casier', 'logit_score': -102.65739913953726, 'lm_score': -135.57672132956145, 'word_offsets': None}, 'alignment': [('suf', None, 'deletion'), ('fari', None, 'deletion'), ('juit', None, 'deletion'), ('lumèce', None, 'deletion'), ('goix', 'nuit', 'substitution'), ('munon', 'reuil', 'substitution'), ('donte', 'donte', 'match'), ('tondé', None, 'deletion'), ('toir', None, 'deletion'), ('rombage', None, 'deletion'), ('jeur', 'bouprêeale', 'substitution'), ('brète', 'casier', 'substitution')]}]
# Processing file:  3183_edugame2023_3563f33d555d42b0bc375b13507c06f6_2150fb9cbb3c4cca8638862aae1d0752.wav
# ASR response:  [{'transcription': {'text': "jen'aipas compris ce qu'ilfallait faireicidans cetexercice donte intdevant toide haut en baie joie laitu le disàl'oral amicro", 'logit_score': -195.40783442996604, 'lm_score': -385.03822889060666, 'word_offsets': None}, 'alignment': [(None, 'jen', 'insertion'), (None, 'aipas', 'insertion'), (None, 'compris', 'insertion'), (None, 'ce', 'insertion'), (None, 'qu', 'insertion'), (None, 'ilfallait', 'insertion'), (None, 'faireicidans', 'insertion'), (None, 'cetexercice', 'insertion'), ('toit', 'donte', 'substitution'), ('régal', 'intdevant', 'substitution'), ('juin', 'toide', 'substitution'), ('escapade', 'haut', 'substitution'), ('navet', 'en', 'substitution'), ('pente', 'baie', 'substitution'), ('bandit', 'joie', 'substitution'), ('chaleur', 'laitu', 'substitution'), ('carré', 'le', 'substitution'), ('choix', 'disàl', 'substitution'), ('parade', 'oral', 'substitution'), ('fossile', 'amicro', 'substitution')]}]
# Processing file:  3401_edugame2023_3d3600a19e43465eb5c4f0eb9473ece9_0d1a5a577a034f7f96dafa49b0022add.wav
# ASR response:  [{'transcription': {'text': 'tabac', 'logit_score': -68.43066000678496, 'lm_score': -71.72668039764164, 'word_offsets': None}, 'alignment': [('baie', None, 'deletion'), ('frère', None, 'deletion'), ('nombre', None, 'deletion'), ('commande', None, 'deletion'), ('stade', None, 'deletion'), ('crêpe', None, 'deletion'), ('valeur', None, 'deletion'), ('caravelle', None, 'deletion'), ('élève', None, 'deletion'), ('pardon', None, 'deletion'), ('pinson', None, 'deletion'), ('mission', 'tabac', 'substitution')]}]
# Processing file:  3401_edugame2023_3d3600a19e43465eb5c4f0eb9473ece9_1ed0a66932f0458990302d4e63b0820c.wav
# ASR response:  [{'transcription': {'text': '', 'logit_score': -74.11931481339832, 'lm_score': -88.9271178663655, 'word_offsets': None}, 'alignment': [('piège', None, 'deletion'), ('femme', None, 'deletion'), ('secret', None, 'deletion'), ('finit', None, 'deletion'), ('mille', None, 'deletion'), ('cerf', None, 'deletion'), ('jardin', None, 'deletion'), ('précision', None, 'deletion'), ('dix', None, 'deletion'), ('lieux', None, 'deletion'), ('million', None, 'deletion'), ('débarquement', None, 'deletion')]}]
# Processing file:  3401_edugame2023_3d3600a19e43465eb5c4f0eb9473ece9_87ff726ba2a349c4aaba95553ddb6c8b.wav
# ASR response:  [{'transcription': {'text': 'lait', 'logit_score': -45.488031884905986, 'lm_score': -60.601085758647216, 'word_offsets': None}, 'alignment': [('escroc', None, 'deletion'), ('tabac', None, 'deletion'), ('reconnaissance', None, 'deletion'), ('apparition', None, 'deletion'), ('blanc', None, 'deletion'), ('poids', None, 'deletion'), ('couette', None, 'deletion'), ('chemisier', None, 'deletion'), ('rosier', None, 'deletion'), ('écuyère', None, 'deletion'), ('catastrophe', None, 'deletion'), ('déclaration', 'lait', 'substitution')]}]
# Processing file:  3402_edugame2023_7cd15abe93744d9c91f5e915fc9511df_55a7cc70b20d420ea5a077ed8ff8b3c6.wav
# ASR response:  [{'transcription': {'text': "moijevoaisen fait est-ce quevousvoulez savoir pourquoi n'éteiz pas là anoui j'aiuchapela castroji baie sept fois", 'logit_score': -80.92629590399613, 'lm_score': -268.9836018982555, 'word_offsets': None}, 'alignment': [(None, 'moijevoaisen', 'insertion'), (None, 'fait', 'insertion'), (None, 'est', 'insertion'), (None, 'ce', 'insertion'), (None, 'quevousvoulez', 'insertion'), (None, 'savoir', 'insertion'), ('gigot', 'pourquoi', 'substitution'), ('duvet', 'n', 'substitution'), ('convalescence', 'éteiz', 'substitution'), ('excitation', 'pas', 'substitution'), ('tronc', 'là', 'substitution'), ('poire', 'anoui', 'substitution'), ('mouette', 'j', 'substitution'), ('menuisier', 'aiuchapela', 'substitution'), ('casier', 'castroji', 'substitution'), ('equateur', 'baie', 'substitution'), ('orchestre', 'sept', 'substitution'), ('réclamation', 'fois', 'substitution')]}]
# Processing file:  3405_edugame2023_222571f93b1649dd88e4c12a8cdf0774_19c827048ecb4e6c8fd31d7843087427.wav
# ASR response:  [{'transcription': {'text': 'tuasfarstoutes les pages chambre demande equateur manivelle hôtel cordon chanson', 'logit_score': -72.84848557199061, 'lm_score': -129.80045721591856, 'word_offsets': None}, 'alignment': [(None, 'tuasfarstoutes', 'insertion'), ('haie', 'les', 'substitution'), ('brume', 'pages', 'substitution'), ('chambre', 'chambre', 'match'), ('demande', 'demande', 'match'), ('style', None, 'deletion'), ('crâne', None, 'deletion'), ('fureur', 'equateur', 'substitution'), ('manivelle', 'manivelle', 'match'), ('hôtel', 'hôtel', 'match'), ('cordon', 'cordon', 'match'), ('chanson', 'chanson', 'match'), ('pommier', None, 'deletion')]}]
# Processing file:  3405_edugame2023_222571f93b1649dd88e4c12a8cdf0774_88c17ecf50ea47c6b85b29c99db78b27.wav
# ASR response:  [{'transcription': {'text': "dessirgois jen'ai pas comprisla mois'est toujours pareil jusqu'emok ldessirgois élope escalope béret", 'logit_score': -106.44568928113156, 'lm_score': -254.2926188056685, 'word_offsets': None}, 'alignment': [(None, 'dessirgois', 'insertion'), (None, 'jen', 'insertion'), (None, 'ai', 'insertion'), ('lait', 'pas', 'substitution'), ('désir', 'comprisla', 'substitution'), ('joie', 'mois', 'substitution'), ('escalope', 'est', 'substitution'), ('béret', 'toujours', 'substitution'), ('vente', 'pareil', 'substitution'), ('boulot', 'jusqu', 'substitution'), ('bonheur', 'emok', 'substitution'), ('pâté', 'ldessirgois', 'substitution'), ('voix', 'élope', 'substitution'), ('façade', 'escalope', 'substitution'), ('argile', 'béret', 'substitution')]}]
# Processing file:  3408_edugame2023_9827c093daf94dbabc906a6b2525a84f_31a0c0cf0e1f452a927647f6cdbc2d47.wav
# ASR response:  [{'transcription': {'text': 'verti', 'logit_score': -1.2860724816680262, 'lm_score': -29.178746766060566, 'word_offsets': None}, 'alignment': [('piège', None, 'deletion'), ('femme', None, 'deletion'), ('secret', None, 'deletion'), ('finit', None, 'deletion'), ('mille', None, 'deletion'), ('cerf', None, 'deletion'), ('jardin', None, 'deletion'), ('précision', None, 'deletion'), ('dix', None, 'deletion'), ('lieux', None, 'deletion'), ('million', None, 'deletion'), ('débarquement', 'verti', 'substitution')]}]
# Processing file:  3411_edugame2023_dc2803354f504d52b183f115e06fe140_8bc4a0ee5a20402b9c00010e4f64ddb2.wav
# ASR response:  [{'transcription': {'text': 'jussari joie coeuplus foire donte tondé toir rombage gerbrebret', 'logit_score': -121.35250786558704, 'lm_score': -177.67401377732054, 'word_offsets': None}, 'alignment': [('suf', None, 'deletion'), ('fari', None, 'deletion'), ('juit', 'jussari', 'substitution'), ('lumèce', 'joie', 'substitution'), ('goix', 'coeuplus', 'substitution'), ('munon', 'foire', 'substitution'), ('donte', 'donte', 'match'), ('tondé', 'tondé', 'match'), ('toir', 'toir', 'match'), ('rombage', 'rombage', 'match'), ('jeur', None, 'deletion'), ('brète', 'gerbrebret', 'substitution')]}]
# Processing file:  3419_edugame2023_40f93372b025445fb3db8b5b58899b23_08e6343b06f14682ba80909e26b2b938.wav
# ASR response:  [{'transcription': {'text': 'puparfaire pourquand pasde choumoi jardin mesnefs toit passije veux pasdire saimême paroce peuxappuyer ma vente faqueje puiscriseapi même sijepali', 'logit_score': -260.9448004420606, 'lm_score': -478.31802583193326, 'word_offsets': None}, 'alignment': [(None, 'puparfaire', 'insertion'), (None, 'pourquand', 'insertion'), (None, 'pasde', 'insertion'), (None, 'choumoi', 'insertion'), (None, 'jardin', 'insertion'), (None, 'mesnefs', 'insertion'), (None, 'toit', 'insertion'), ('gigot', 'passije', 'substitution'), ('duvet', 'veux', 'substitution'), ('convalescence', 'pasdire', 'substitution'), ('excitation', 'saimême', 'substitution'), ('tronc', 'paroce', 'substitution'), ('poire', 'peuxappuyer', 'substitution'), ('mouette', 'ma', 'substitution'), ('menuisier', 'vente', 'substitution'), ('casier', 'faqueje', 'substitution'), ('equateur', 'puiscriseapi', 'substitution'), ('orchestre', 'même', 'substitution'), ('réclamation', 'sijepali', 'substitution')]}]
# Processing file:  3419_edugame2023_c0fd5fc65b334f35a33b1771182b078d_e89b5115b4d54a549a74e92e9c941095.wav
# ASR response:  [{'transcription': {'text': 'bassurel-davo dino transporté tienge-rojo meilleur trefodulent hupeur mive rari', 'logit_score': -47.52374369952748, 'lm_score': -144.56425564184417, 'word_offsets': None}, 'alignment': [('bucurelle', 'bassurel', 'substitution'), ('daveau', 'davo', 'substitution'), ('ninoie', 'dino', 'substitution'), ('trefonet', 'transporté', 'substitution'), ('tiège', 'tienge', 'substitution'), ('ronjeau', 'rojo', 'substitution'), ('meuil', 'meilleur', 'substitution'), ('trufondulence', 'trefodulent', 'substitution'), ('hupeur', 'hupeur', 'match'), ('mive', 'mive', 'match'), ('gralation', None, 'deletion'), ('turlème', 'rari', 'substitution')]}]
# Processing file:  3422_edugame2023_23a5cea0e1174d71827c4fd50f709a87_287254c8f22d48ef80881eb6e97f6ecf.wav
# ASR response:  [{'transcription': {'text': 'alors joue pente pente sapoapositon grève voichate duie ceraon instrêment malédiction', 'logit_score': -137.35109259223248, 'lm_score': -227.02178260061407, 'word_offsets': None}, 'alignment': [('écho', None, 'deletion'), ('logis', 'alors', 'substitution'), ('intelligence', 'joue', 'substitution'), ('opposition', 'pente', 'substitution'), ('creux', 'pente', 'substitution'), ('foire', 'sapoapositon', 'substitution'), ('chouette', 'grève', 'substitution'), ('cuisinier', 'voichate', 'substitution'), ('cellier', 'duie', 'substitution'), ('estragon', 'ceraon', 'substitution'), ('instruments', 'instrêment', 'substitution'), ('malédiction', 'malédiction', 'match')]}]
# Processing file:  3422_edugame2023_23a5cea0e1174d71827c4fd50f709a87_4fda7cc17ff64052a98815bc5e76e278.wav
# ASR response:  [{'transcription': {'text': 'cetcumitare escalade', 'logit_score': -74.86948033770959, 'lm_score': -104.33524308848341, 'word_offsets': None}, 'alignment': [('siège', None, 'deletion'), ('coeur', None, 'deletion'), ('basket', None, 'deletion'), ('récit', None, 'deletion'), ('sept', None, 'deletion'), ('clef', None, 'deletion'), ('gourdin', None, 'deletion'), ('tradition', None, 'deletion'), ('six', None, 'deletion'), ('cieux', None, 'deletion'), ('moisson', 'cetcumitare', 'substitution'), ('département', 'escalade', 'substitution')]}]
# Processing file:  3423_edugame2023_f35ebc6aefeb4aeb88d6fb92344210ba_f6018cdc39fa4d078f3b4ddaf4d30c9e.wav
# ASR response:  [{'transcription': {'text': '', 'logit_score': -30.542354035456537, 'lm_score': -45.35015708842373, 'word_offsets': None}, 'alignment': [('baie', None, 'deletion'), ('frère', None, 'deletion'), ('nombre', None, 'deletion'), ('commande', None, 'deletion'), ('stade', None, 'deletion'), ('crêpe', None, 'deletion'), ('valeur', None, 'deletion'), ('caravelle', None, 'deletion'), ('élève', None, 'deletion'), ('pardon', None, 'deletion'), ('pinson', None, 'deletion'), ('mission', None, 'deletion')]}]
# Processing file:  3710_edugame2023_fe4a2cef3a9240f1813990423ba593f4_af337f62fb514c7cad6e1284e31f17b7.wav
# ASR response:  [{'transcription': {'text': '', 'logit_score': -93.66664265653807, 'lm_score': -108.47444570950526, 'word_offsets': None}, 'alignment': [('haie', None, 'deletion'), ('brume', None, 'deletion'), ('chambre', None, 'deletion'), ('demande', None, 'deletion'), ('style', None, 'deletion'), ('crâne', None, 'deletion'), ('fureur', None, 'deletion'), ('manivelle', None, 'deletion'), ('hôtel', None, 'deletion'), ('cordon', None, 'deletion'), ('chanson', None, 'deletion'), ('pommier', None, 'deletion')]}]
# Processing file:  3712_edugame2023_4f3851d570c245669a22facf5ea996c1_0c102523084f45eeb240a95de1b36afb.wav
# ASR response:  [{'transcription': {'text': 'abasmapala lardon tuit', 'logit_score': -96.25262730471132, 'lm_score': -114.20660739337464, 'word_offsets': None}, 'alignment': [('raie', None, 'deletion'), ('grève', None, 'deletion'), ('timbre', None, 'deletion'), ('légende', None, 'deletion'), ('stand', None, 'deletion'), ('crête', None, 'deletion'), ('voleur', None, 'deletion'), ('mirabelle', None, 'deletion'), ('amour', 'abasmapala', 'substitution'), ('lardon', 'lardon', 'match'), ('saison', None, 'deletion'), ('pompier', 'tuit', 'substitution')]}]
# Processing file:  3712_edugame2023_4f3851d570c245669a22facf5ea996c1_d5ff7f535b524e7897ee1058042f875a.wav
# ASR response:  [{'transcription': {'text': "raie stade faire quelques mois gigot duvet qu'onvalesquand toir trompenit", 'logit_score': -194.11563249934014, 'lm_score': -266.821782830568, 'word_offsets': None}, 'alignment': [('gigot', None, 'deletion'), ('duvet', 'raie', 'substitution'), ('convalescence', 'stade', 'substitution'), ('excitation', 'faire', 'substitution'), ('tronc', 'quelques', 'substitution'), ('poire', 'mois', 'substitution'), ('mouette', 'gigot', 'substitution'), ('menuisier', 'duvet', 'substitution'), ('casier', 'qu', 'substitution'), ('equateur', 'onvalesquand', 'substitution'), ('orchestre', 'toir', 'substitution'), ('réclamation', 'trompenit', 'substitution')]}]
# Processing file:  3712_edugame2023_4f3851d570c245669a22facf5ea996c1_fa8506b5f2594453a50d90adf4823e15.wav
# ASR response:  [{'transcription': {'text': "c'estpas sequ'onvous demande métait trop durec'est impossible menuisier seconcentrer jeulivredisai liège c'estquoi dumatériau peucommedu boisesort soruecran nuit jenesuispas", 'logit_score': -191.4372860285325, 'lm_score': -395.7256401869797, 'word_offsets': None}, 'alignment': [(None, 'c', 'insertion'), (None, 'estpas', 'insertion'), (None, 'sequ', 'insertion'), (None, 'onvous', 'insertion'), (None, 'demande', 'insertion'), (None, 'métait', 'insertion'), (None, 'trop', 'insertion'), (None, 'durec', 'insertion'), (None, 'est', 'insertion'), (None, 'impossible', 'insertion'), ('liège', 'menuisier', 'substitution'), ('soeur', 'seconcentrer', 'substitution'), ('regret', 'jeulivredisai', 'substitution'), ('fusil', 'liège', 'substitution'), ('fils', 'c', 'substitution'), ('août', 'estquoi', 'substitution'), ('garçon', 'dumatériau', 'substitution'), ('production', 'peucommedu', 'substitution'), ('gaz', 'boisesort', 'substitution'), ('dieux', 'soruecran', 'substitution'), ('tension', 'nuit', 'substitution'), ('déménagement', 'jenesuispas', 'substitution')]}]
# Processing file:  3712_edugame2023_c2494bdd86444702b6e6c648b1bace8b_5d9776fc9a434b7c8a0413b9957058da.wav
# ASR response:  [{'transcription': {'text': "jecroisetc'est demotbizarre commande mission", 'logit_score': -141.0799897457281, 'lm_score': -185.20371219430857, 'word_offsets': None}, 'alignment': [('bucurelle', None, 'deletion'), ('daveau', None, 'deletion'), ('ninoie', None, 'deletion'), ('trefonet', None, 'deletion'), ('tiège', None, 'deletion'), ('ronjeau', None, 'deletion'), ('meuil', None, 'deletion'), ('trufondulence', 'jecroisetc', 'substitution'), ('hupeur', 'est', 'substitution'), ('mive', 'demotbizarre', 'substitution'), ('gralation', 'commande', 'substitution'), ('turlème', 'mission', 'substitution')]}]
# Processing file:  3722_edugame2023_acfa4d88f33c4ce29aa11669cd4ef43b_e63b1cd0ccad48e48384008aa94181b9.wav
# ASR response:  [{'transcription': {'text': "escalope lait parlerpeuplus pardon vente tente anle microd'accord tente vente boulot toir façade", 'logit_score': -228.3698475982347, 'lm_score': -284.1225151053526, 'word_offsets': None}, 'alignment': [(None, 'escalope', 'insertion'), ('lait', 'lait', 'match'), (None, 'parlerpeuplus', 'insertion'), ('désir', 'pardon', 'substitution'), ('joie', 'vente', 'substitution'), ('escalope', 'tente', 'substitution'), ('béret', 'anle', 'substitution'), ('vente', 'microd', 'substitution'), ('boulot', 'accord', 'substitution'), ('bonheur', 'tente', 'substitution'), ('pâté', 'vente', 'substitution'), ('voix', 'boulot', 'substitution'), ('façade', 'toir', 'substitution'), ('argile', 'façade', 'substitution')]}]
# Processing file:  3736_edugame2023_28885fed2d7d4f1c8ad5a797f6154114_744f0ae95b4549b9af552460340bcc03.wav
# ASR response:  [{'transcription': {'text': 'lashigadalaa puli tive', 'logit_score': -70.13003432187475, 'lm_score': -88.08401441053806, 'word_offsets': None}, 'alignment': [('sidomelle', None, 'deletion'), ('tiveau', None, 'deletion'), ('firoie', None, 'deletion'), ('timpunet', None, 'deletion'), ('phème', None, 'deletion'), ('tanjeau', None, 'deletion'), ('reuil', None, 'deletion'), ('flunobirence', None, 'deletion'), ('hopeur', None, 'deletion'), ('nive', 'lashigadalaa', 'substitution'), ('jorcation', 'puli', 'substitution'), ('raplème', 'tive', 'substitution')]}]
# Processing file:  3736_edugame2023_28885fed2d7d4f1c8ad5a797f6154114_da834e4808d545bdb3e299f2b691a2c1.wav
# ASR response:  [{'transcription': {'text': 'amour stade crêpe valeur paroce valet élève pardon', 'logit_score': -81.93424169455228, 'lm_score': -91.07598387142288, 'word_offsets': None}, 'alignment': [('suf', None, 'deletion'), ('fari', None, 'deletion'), ('juit', None, 'deletion'), ('lumèce', None, 'deletion'), ('goix', 'amour', 'substitution'), ('munon', 'stade', 'substitution'), ('donte', 'crêpe', 'substitution'), ('tondé', 'valeur', 'substitution'), ('toir', 'paroce', 'substitution'), ('rombage', 'valet', 'substitution'), ('jeur', 'élève', 'substitution'), ('brète', 'pardon', 'substitution')]}]
# Processing file:  3736_edugame2023_2ab07416804c4c849c46e0f9170cb3ec_6bf0e1e1164c493f80ab6eee249ee8fd.wav
# ASR response:  [{'transcription': {'text': 'mive', 'logit_score': -15.620612059267026, 'lm_score': -32.00150357861549, 'word_offsets': None}, 'alignment': [('escroc', None, 'deletion'), ('tabac', None, 'deletion'), ('reconnaissance', None, 'deletion'), ('apparition', None, 'deletion'), ('blanc', None, 'deletion'), ('poids', None, 'deletion'), ('couette', None, 'deletion'), ('chemisier', None, 'deletion'), ('rosier', None, 'deletion'), ('écuyère', None, 'deletion'), ('catastrophe', None, 'deletion'), ('déclaration', 'mive', 'substitution')]}]
# Processing file:  3736_edugame2023_2ab07416804c4c849c46e0f9170cb3ec_6c859b00d721421f84ca25f92100d568.wav
# ASR response:  [{'transcription': {'text': 'intest-ceque cestlstdur six toir', 'logit_score': -195.33969018321352, 'lm_score': -239.46341263179397, 'word_offsets': None}, 'alignment': [('nuit', None, 'deletion'), ('métal', None, 'deletion'), ('joue', None, 'deletion'), ('escalade', None, 'deletion'), ('valet', None, 'deletion'), ('tente', None, 'deletion'), ('jaloux', None, 'deletion'), ('couleur', 'intest', 'substitution'), ('fossé', 'ceque', 'substitution'), ('noix', 'cestlstdur', 'substitution'), ('balade', 'six', 'substitution'), ('reptile', 'toir', 'substitution')]}]
# Processing file:  3736_edugame2023_2ab07416804c4c849c46e0f9170cb3ec_a3079f2cea0c472aa8fd236fdac875d7.wav
# ASR response:  [{'transcription': {'text': 'cevava saison', 'logit_score': -57.75984864269407, 'lm_score': -74.1407402649761, 'word_offsets': None}, 'alignment': [('piège', None, 'deletion'), ('femme', None, 'deletion'), ('secret', None, 'deletion'), ('finit', None, 'deletion'), ('mille', None, 'deletion'), ('cerf', None, 'deletion'), ('jardin', None, 'deletion'), ('précision', None, 'deletion'), ('dix', None, 'deletion'), ('lieux', None, 'deletion'), ('million', 'cevava', 'substitution'), ('débarquement', 'saison', 'substitution')]}]
# Processing file:  3736_edugame2023_2ab07416804c4c849c46e0f9170cb3ec_b9c2d4e4c0ee446f9b61aa28517c3bc1.wav
# ASR response:  [{'transcription': {'text': 'blabondaid frère nombre vas fini', 'logit_score': -157.78695409206063, 'lm_score': -200.85989207659605, 'word_offsets': None}, 'alignment': [('baie', 'blabondaid', 'substitution'), ('frère', 'frère', 'match'), ('nombre', 'nombre', 'match'), ('commande', None, 'deletion'), ('stade', None, 'deletion'), ('crêpe', None, 'deletion'), ('valeur', None, 'deletion'), ('caravelle', None, 'deletion'), ('élève', None, 'deletion'), ('pardon', None, 'deletion'), ('pinson', 'vas', 'substitution'), ('mission', 'fini', 'substitution')]}]
# Processing file:  3738_edugame2023_2b7f897c8b74431697be15e3ccf65a4f_de942c4248ed47a3a136de2c8a5762ab.wav
# ASR response:  [{'transcription': {'text': 'lait trefonet puli tente mille', 'logit_score': -122.1840426115323, 'lm_score': -130.50457922230686, 'word_offsets': None}, 'alignment': [('haie', None, 'deletion'), ('brume', None, 'deletion'), ('chambre', None, 'deletion'), ('demande', None, 'deletion'), ('style', None, 'deletion'), ('crâne', None, 'deletion'), ('fureur', None, 'deletion'), ('manivelle', 'lait', 'substitution'), ('hôtel', 'trefonet', 'substitution'), ('cordon', 'puli', 'substitution'), ('chanson', 'tente', 'substitution'), ('pommier', 'mille', 'substitution')]}]
# Processing file:  3738_edugame2023_9b9134c4b2f642b9989b21acb9977745_223177e1faf94ef29db00a43b4b0adb3.wav
# ASR response:  [{'transcription': {'text': 'juit envieedonc', 'logit_score': -25.42930558941513, 'lm_score': -54.89506834018894, 'word_offsets': None}, 'alignment': [('digacelle', None, 'deletion'), ('pireau', None, 'deletion'), ('lisoie', None, 'deletion'), ('milvenet', None, 'deletion'), ('diège', None, 'deletion'), ('conjeau', None, 'deletion'), ('beuil', None, 'deletion'), ('brumidurence', None, 'deletion'), ('héteur', None, 'deletion'), ('tive', None, 'deletion'), ('pléfation', 'juit', 'substitution'), ('sorpile', 'envieedonc', 'substitution')]}]
# Processing file:  3738_edugame2023_9b9134c4b2f642b9989b21acb9977745_9011d9a78251420c811fd7d8e76759b4.wav
# ASR response:  [{'transcription': {'text': 'lamon', 'logit_score': -40.70687847292375, 'lm_score': -44.00289886378044, 'word_offsets': None}, 'alignment': [('jol', None, 'deletion'), ('puli', None, 'deletion'), ('ruit', None, 'deletion'), ('paroce', None, 'deletion'), ('reux', None, 'deletion'), ('lamon', 'lamon', 'match'), ('bente', None, 'deletion'), ('nardé', None, 'deletion'), ('duie', None, 'deletion'), ('anglage', None, 'deletion'), ('jauf', None, 'deletion'), ('trèbe', None, 'deletion')]}]
# Processing file:  3739_edugame2023_19c2eb116c864c6da505f5c083e808a4_7c3a35ef4c0a436abb4882cbe48bf8b3.wav
# ASR response:  [{'transcription': {'text': 'cordutabel chapeludi tente demande vousavez parade lamon navet vente trème pardon lait comprendre bente vente duie', 'logit_score': -518.0815591474284, 'lm_score': -604.1059087226723, 'word_offsets': None}, 'alignment': [('haie', 'cordutabel', 'substitution'), ('brume', 'chapeludi', 'substitution'), ('chambre', 'tente', 'substitution'), ('demande', 'demande', 'match'), (None, 'vousavez', 'insertion'), (None, 'parade', 'insertion'), (None, 'lamon', 'insertion'), (None, 'navet', 'insertion'), ('style', 'vente', 'substitution'), ('crâne', 'trème', 'substitution'), ('fureur', 'pardon', 'substitution'), ('manivelle', 'lait', 'substitution'), ('hôtel', 'comprendre', 'substitution'), ('cordon', 'bente', 'substitution'), ('chanson', 'vente', 'substitution'), ('pommier', 'duie', 'substitution')]}]
# Processing file:  3739_edugame2023_19c2eb116c864c6da505f5c083e808a4_8acb70826615486ab60952cb128f02fa.wav
# ASR response:  [{'transcription': {'text': 'bente commande tuit', 'logit_score': -321.3304009728027, 'lm_score': -327.7725982964219, 'word_offsets': None}, 'alignment': [('écho', None, 'deletion'), ('logis', None, 'deletion'), ('intelligence', None, 'deletion'), ('opposition', None, 'deletion'), ('creux', None, 'deletion'), ('foire', None, 'deletion'), ('chouette', None, 'deletion'), ('cuisinier', None, 'deletion'), ('cellier', None, 'deletion'), ('estragon', 'bente', 'substitution'), ('instruments', 'commande', 'substitution'), ('malédiction', 'tuit', 'substitution')]}]
# Processing file:  3739_edugame2023_e98bb4ab323147f989df4986d7289e26_1806ad601fb24920880318625c27e945.wav
# ASR response:  [{'transcription': {'text': 'toit vasaorplus raie raie raie donte pe', 'logit_score': -187.1902909302938, 'lm_score': -221.68140778028516, 'word_offsets': None}, 'alignment': [('digacelle', None, 'deletion'), ('pireau', None, 'deletion'), ('lisoie', None, 'deletion'), ('milvenet', None, 'deletion'), ('diège', None, 'deletion'), ('conjeau', 'toit', 'substitution'), ('beuil', 'vasaorplus', 'substitution'), ('brumidurence', 'raie', 'substitution'), ('héteur', 'raie', 'substitution'), ('tive', 'raie', 'substitution'), ('pléfation', 'donte', 'substitution'), ('sorpile', 'pe', 'substitution')]}]
# Processing file:  3739_edugame2023_e98bb4ab323147f989df4986d7289e26_3a1a9de31d604daeb7aafa4ba0f16faa.wav
# ASR response:  [{'transcription': {'text': 'juin duie raie poids daveau chouette', 'logit_score': -152.56954673041773, 'lm_score': -163.73100945318077, 'word_offsets': None}, 'alignment': [('jol', None, 'deletion'), ('puli', None, 'deletion'), ('ruit', None, 'deletion'), ('paroce', None, 'deletion'), ('reux', None, 'deletion'), ('lamon', None, 'deletion'), ('bente', 'juin', 'substitution'), ('nardé', 'duie', 'substitution'), ('duie', 'raie', 'substitution'), ('anglage', 'poids', 'substitution'), ('jauf', 'daveau', 'substitution'), ('trèbe', 'chouette', 'substitution')]}]
# Processing file:  3743_edugame2023_34d51ecbe2134f0bad8f4fcde04571ce_058212d525274aa3957b2761b97e6ce0.wav
# ASR response:  [{'transcription': {'text': 'regret ouipourt bente pente duie', 'logit_score': -303.39478706338093, 'lm_score': -324.4949440848068, 'word_offsets': None}, 'alignment': [('rof', None, 'deletion'), ('rari', None, 'deletion'), ('tuit', None, 'deletion'), ('cutice', None, 'deletion'), ('zeux', None, 'deletion'), ('bumon', None, 'deletion'), ('bante', None, 'deletion'), ('perné', 'regret', 'substitution'), ('loif', 'ouipourt', 'substitution'), ('bonfage', 'bente', 'substitution'), ('jeul', 'pente', 'substitution'), ('trème', 'duie', 'substitution')]}]
# Processing file:  3743_edugame2023_34d51ecbe2134f0bad8f4fcde04571ce_11efd96646964862aec555b5a3fc4f47.wav
# ASR response:  [{'transcription': {'text': "pente bumon raie correspond lieux fossile raie toit m'appelle", 'logit_score': -143.98072648831942, 'lm_score': -182.88502003738088, 'word_offsets': None}, 'alignment': [('bucurelle', None, 'deletion'), ('daveau', None, 'deletion'), ('ninoie', 'pente', 'substitution'), ('trefonet', 'bumon', 'substitution'), ('tiège', 'raie', 'substitution'), ('ronjeau', 'correspond', 'substitution'), ('meuil', 'lieux', 'substitution'), ('trufondulence', 'fossile', 'substitution'), ('hupeur', 'raie', 'substitution'), ('mive', 'toit', 'substitution'), ('gralation', 'm', 'substitution'), ('turlème', 'appelle', 'substitution')]}]
# Processing file:  3743_edugame2023_4b770956576f485abe959ae98eb1c743_1dc95a63ec534236a5494f80e3dee49b.wav
# ASR response:  [{'transcription': {'text': 'nuit', 'logit_score': -144.24434709134593, 'lm_score': -146.27466169386514, 'word_offsets': None}, 'alignment': [('gigot', None, 'deletion'), ('duvet', None, 'deletion'), ('convalescence', None, 'deletion'), ('excitation', None, 'deletion'), ('tronc', None, 'deletion'), ('poire', None, 'deletion'), ('mouette', None, 'deletion'), ('menuisier', None, 'deletion'), ('casier', None, 'deletion'), ('equateur', None, 'deletion'), ('orchestre', None, 'deletion'), ('réclamation', 'nuit', 'substitution')]}]
# Processing file:  3743_edugame2023_4b770956576f485abe959ae98eb1c743_418b7b26db254bf6a219bd0ddb1078f1.wav
# ASR response:  [{'transcription': {'text': 'tejepeuvdire commentfaire essaededire lesmoqeurs sept toit meuil tente meuil', 'logit_score': -212.51708634839608, 'lm_score': -287.5298166589711, 'word_offsets': None}, 'alignment': [('toit', None, 'deletion'), ('régal', None, 'deletion'), ('juin', None, 'deletion'), ('escapade', 'tejepeuvdire', 'substitution'), ('navet', 'commentfaire', 'substitution'), ('pente', 'essaededire', 'substitution'), ('bandit', 'lesmoqeurs', 'substitution'), ('chaleur', 'sept', 'substitution'), ('carré', 'toit', 'substitution'), ('choix', 'meuil', 'substitution'), ('parade', 'tente', 'substitution'), ('fossile', 'meuil', 'substitution')]}]
# Processing file:  3743_edugame2023_4b770956576f485abe959ae98eb1c743_4397bd6653534140ab00369ea1b0cce1.wav
# ASR response:  [{'transcription': {'text': 'tente carré mantiennent des', 'logit_score': -76.34081236514113, 'lm_score': -107.37966358229622, 'word_offsets': None}, 'alignment': [('liège', None, 'deletion'), ('soeur', None, 'deletion'), ('regret', None, 'deletion'), ('fusil', None, 'deletion'), ('fils', None, 'deletion'), ('août', None, 'deletion'), ('garçon', None, 'deletion'), ('production', None, 'deletion'), ('gaz', 'tente', 'substitution'), ('dieux', 'carré', 'substitution'), ('tension', 'mantiennent', 'substitution'), ('déménagement', 'des', 'substitution')]}]
# Processing file:  3743_edugame2023_4b770956576f485abe959ae98eb1c743_fd2f269ed6534805a37daf43985d7668.wav
# ASR response:  [{'transcription': {'text': 'baie donte', 'logit_score': -105.51182126747545, 'lm_score': -109.11596309064299, 'word_offsets': None}, 'alignment': [('raie', None, 'deletion'), ('grève', None, 'deletion'), ('timbre', None, 'deletion'), ('légende', None, 'deletion'), ('stand', None, 'deletion'), ('crête', None, 'deletion'), ('voleur', None, 'deletion'), ('mirabelle', None, 'deletion'), ('amour', None, 'deletion'), ('lardon', None, 'deletion'), ('saison', 'baie', 'substitution'), ('pompier', 'donte', 'substitution')]}]
# Processing file:  3748_edugame2023_1e9af07520274b5e8c955a7d895e62ff_00475c111dba4b2a9e903d4e6b991417.wav
# ASR response:  [{'transcription': {'text': "ilfautbienque dises les motsal'accord an micro pardon poire ruit casier lai", 'logit_score': -118.33448602801961, 'lm_score': -217.94387033506405, 'word_offsets': None}, 'alignment': [('gigot', 'ilfautbienque', 'substitution'), ('duvet', 'dises', 'substitution'), ('convalescence', 'les', 'substitution'), ('excitation', 'motsal', 'substitution'), ('tronc', 'accord', 'substitution'), ('poire', 'an', 'substitution'), ('mouette', 'micro', 'substitution'), ('menuisier', 'pardon', 'substitution'), ('casier', 'poire', 'substitution'), ('equateur', 'ruit', 'substitution'), ('orchestre', 'casier', 'substitution'), ('réclamation', 'lai', 'substitution')]}]
# Processing file:  3750_edugame2023_2ad2ce388fb043c38be72ad25fe22cef_580b2d0f788b4273b98f5d017bf52f95.wav
# ASR response:  [{'transcription': {'text': 'ah a', 'logit_score': -35.20455555865895, 'lm_score': -63.097229843051494, 'word_offsets': None}, 'alignment': [('écho', None, 'deletion'), ('logis', None, 'deletion'), ('intelligence', None, 'deletion'), ('opposition', None, 'deletion'), ('creux', None, 'deletion'), ('foire', None, 'deletion'), ('chouette', None, 'deletion'), ('cuisinier', None, 'deletion'), ('cellier', None, 'deletion'), ('estragon', None, 'deletion'), ('instruments', 'ah', 'substitution'), ('malédiction', 'a', 'substitution')]}]
# Processing file:  3750_edugame2023_2ad2ce388fb043c38be72ad25fe22cef_a58396ba7c1e43db8c73f68c90c44bfd.wav
# ASR response:  [{'transcription': {'text': '', 'logit_score': -41.895778775896595, 'lm_score': -56.70358182886378, 'word_offsets': None}, 'alignment': [('siège', None, 'deletion'), ('coeur', None, 'deletion'), ('basket', None, 'deletion'), ('récit', None, 'deletion'), ('sept', None, 'deletion'), ('clef', None, 'deletion'), ('gourdin', None, 'deletion'), ('tradition', None, 'deletion'), ('six', None, 'deletion'), ('cieux', None, 'deletion'), ('moisson', None, 'deletion'), ('département', None, 'deletion')]}]
# Processing file:  3750_edugame2023_c82f211c49324a14a89684e3c146ab89_5f10cd3f9d5149e6ac78b06124c34015.wav
# ASR response:  [{'transcription': {'text': 'nuit', 'logit_score': -71.78425850937285, 'lm_score': -86.89944406882786, 'word_offsets': None}, 'alignment': [('jol', None, 'deletion'), ('puli', None, 'deletion'), ('ruit', None, 'deletion'), ('paroce', None, 'deletion'), ('reux', None, 'deletion'), ('lamon', None, 'deletion'), ('bente', None, 'deletion'), ('nardé', None, 'deletion'), ('duie', None, 'deletion'), ('anglage', None, 'deletion'), ('jauf', None, 'deletion'), ('trèbe', 'nuit', 'substitution')]}]
# Processing file:  3750_edugame2023_c82f211c49324a14a89684e3c146ab89_800df8a583dc4acb8004ca011b10ccc8.wav
# ASR response:  [{'transcription': {'text': 'ouiahnéon', 'logit_score': -18.515547016526813, 'lm_score': -46.40822130091935, 'word_offsets': None}, 'alignment': [('digacelle', None, 'deletion'), ('pireau', None, 'deletion'), ('lisoie', None, 'deletion'), ('milvenet', None, 'deletion'), ('diège', None, 'deletion'), ('conjeau', None, 'deletion'), ('beuil', None, 'deletion'), ('brumidurence', None, 'deletion'), ('héteur', None, 'deletion'), ('tive', None, 'deletion'), ('pléfation', None, 'deletion'), ('sorpile', 'ouiahnéon', 'substitution')]}]
# Processing file:  4009_edugame2023_3c2a034bb1cb4cc9b19febaf6bd15e6c_6a7eb7e158b1407a90481b8ffbc9aff5.wav
# ASR response:  [{'transcription': {'text': 'lait aumieux-là si tune voix pasjuste baie gigot tuveux convalescence tiotroupoir mentsuideu casterepuis latéau', 'logit_score': -167.12431401546206, 'lm_score': -306.2935628375566, 'word_offsets': None}, 'alignment': [(None, 'lait', 'insertion'), (None, 'aumieux', 'insertion'), (None, 'là', 'insertion'), ('gigot', 'si', 'substitution'), ('duvet', 'tune', 'substitution'), ('convalescence', 'voix', 'substitution'), ('excitation', 'pasjuste', 'substitution'), ('tronc', 'baie', 'substitution'), ('poire', 'gigot', 'substitution'), ('mouette', 'tuveux', 'substitution'), ('menuisier', 'convalescence', 'substitution'), ('casier', 'tiotroupoir', 'substitution'), ('equateur', 'mentsuideu', 'substitution'), ('orchestre', 'casterepuis', 'substitution'), ('réclamation', 'latéau', 'substitution')]}]
# Processing file:  4009_edugame2023_3c2a034bb1cb4cc9b19febaf6bd15e6c_88c83901edec4e61ada81dd4f2904b41.wav
# ASR response:  [{'transcription': {'text': 'valet reprender fils', 'logit_score': -202.3123861651675, 'lm_score': -233.3512373823226, 'word_offsets': None}, 'alignment': [('liège', None, 'deletion'), ('soeur', None, 'deletion'), ('regret', 'valet', 'substitution'), ('fusil', 'reprender', 'substitution'), ('fils', 'fils', 'match'), ('août', None, 'deletion'), ('garçon', None, 'deletion'), ('production', None, 'deletion'), ('gaz', None, 'deletion'), ('dieux', None, 'deletion'), ('tension', None, 'deletion'), ('déménagement', None, 'deletion')]}]
# Processing file:  4014_edugame2023_26c48faeff8a4b3a82336f3aaf860c1d_cafe2bdd266f45c6a9bdde03e4c55f52.wav
# ASR response:  [{'transcription': {'text': 'toit resteàfaire demathématique soenttrèsouvent côtétupes appuyeslà', 'logit_score': -368.40994055458106, 'lm_score': -448.94818846474874, 'word_offsets': None}, 'alignment': [('digacelle', None, 'deletion'), ('pireau', None, 'deletion'), ('lisoie', None, 'deletion'), ('milvenet', None, 'deletion'), ('diège', None, 'deletion'), ('conjeau', None, 'deletion'), ('beuil', 'toit', 'substitution'), ('brumidurence', 'resteàfaire', 'substitution'), ('héteur', 'demathématique', 'substitution'), ('tive', 'soenttrèsouvent', 'substitution'), ('pléfation', 'côtétupes', 'substitution'), ('sorpile', 'appuyeslà', 'substitution')]}]
# Processing file:  4014_edugame2023_949b55c6bf8b470d8f50ddf6f2d2067b_a8fd2ab7e6104c3ba0a00c64631a4209.wav
# ASR response:  [{'transcription': {'text': 'vente turlème coeur tente lait lisoie', 'logit_score': -391.4273846451756, 'lm_score': -402.5888473679387, 'word_offsets': None}, 'alignment': [('écho', None, 'deletion'), ('logis', None, 'deletion'), ('intelligence', None, 'deletion'), ('opposition', None, 'deletion'), ('creux', None, 'deletion'), ('foire', None, 'deletion'), ('chouette', 'vente', 'substitution'), ('cuisinier', 'turlème', 'substitution'), ('cellier', 'coeur', 'substitution'), ('estragon', 'tente', 'substitution'), ('instruments', 'lait', 'substitution'), ('malédiction', 'lisoie', 'substitution')]}]
# Processing file:  4014_edugame2023_949b55c6bf8b470d8f50ddf6f2d2067b_a9f39e0f47a143ec8d7fba13a8388d53.wav
# ASR response:  [{'transcription': {'text': "hc'estbon lamon tudessend chambre demande dix nive portant cerf", 'logit_score': -114.44718055186225, 'lm_score': -176.9523441990467, 'word_offsets': None}, 'alignment': [('haie', None, 'deletion'), ('brume', None, 'deletion'), ('chambre', 'hc', 'substitution'), ('demande', 'estbon', 'substitution'), ('style', 'lamon', 'substitution'), ('crâne', 'tudessend', 'substitution'), ('fureur', 'chambre', 'substitution'), ('manivelle', 'demande', 'substitution'), ('hôtel', 'dix', 'substitution'), ('cordon', 'nive', 'substitution'), ('chanson', 'portant', 'substitution'), ('pommier', 'cerf', 'substitution')]}]
# Processing file:  4014_edugame2023_949b55c6bf8b470d8f50ddf6f2d2067b_dd876112850845fa971187b974e06693.wav
# ASR response:  [{'transcription': {'text': "pasfairqu'il toit cestbienc'est très bien c'estjupéra tu peux continuer parbien proche ici", 'logit_score': -207.1694050319292, 'lm_score': -367.4838800969565, 'word_offsets': None}, 'alignment': [(None, 'pasfairqu', 'insertion'), (None, 'il', 'insertion'), (None, 'toit', 'insertion'), ('lait', 'cestbienc', 'substitution'), ('désir', 'est', 'substitution'), ('joie', 'très', 'substitution'), ('escalope', 'bien', 'substitution'), ('béret', 'c', 'substitution'), ('vente', 'estjupéra', 'substitution'), ('boulot', 'tu', 'substitution'), ('bonheur', 'peux', 'substitution'), ('pâté', 'continuer', 'substitution'), ('voix', 'parbien', 'substitution'), ('façade', 'proche', 'substitution'), ('argile', 'ici', 'substitution')]}]
# Processing file:  4020_edugame2023_15f6405f1e774b9db1efcca48fa32382_a8054d3d7f9949708a663dda7d81dda0.wav
# ASR response:  [{'transcription': {'text': 'donte', 'logit_score': -32.38950355290612, 'lm_score': -48.77039507225459, 'word_offsets': None}, 'alignment': [('jol', None, 'deletion'), ('puli', None, 'deletion'), ('ruit', None, 'deletion'), ('paroce', None, 'deletion'), ('reux', None, 'deletion'), ('lamon', None, 'deletion'), ('bente', None, 'deletion'), ('nardé', None, 'deletion'), ('duie', None, 'deletion'), ('anglage', None, 'deletion'), ('jauf', None, 'deletion'), ('trèbe', 'donte', 'substitution')]}]
# Processing file:  4020_edugame2023_15f6405f1e774b9db1efcca48fa32382_aaa177341c754da59d516ff7b2b2b2d7.wav
# ASR response:  [{'transcription': {'text': 'argile jauf daveau trème pente demande', 'logit_score': -148.23516891011664, 'lm_score': -172.48150276137147, 'word_offsets': None}, 'alignment': [('digacelle', None, 'deletion'), ('pireau', None, 'deletion'), ('lisoie', None, 'deletion'), ('milvenet', None, 'deletion'), ('diège', None, 'deletion'), ('conjeau', None, 'deletion'), ('beuil', 'argile', 'substitution'), ('brumidurence', 'jauf', 'substitution'), ('héteur', 'daveau', 'substitution'), ('tive', 'trème', 'substitution'), ('pléfation', 'pente', 'substitution'), ('sorpile', 'demande', 'substitution')]}]
# Processing file:  4020_edugame2023_1a1a855bd0e14af685825abea10c2e49_137bbaaabe9f45399bd0b10b1576070f.wav
# ASR response:  [{'transcription': {'text': 'béret tuit joue', 'logit_score': -76.78967758129306, 'lm_score': -96.31674603340407, 'word_offsets': None}, 'alignment': [('écho', None, 'deletion'), ('logis', None, 'deletion'), ('intelligence', None, 'deletion'), ('opposition', None, 'deletion'), ('creux', None, 'deletion'), ('foire', None, 'deletion'), ('chouette', None, 'deletion'), ('cuisinier', None, 'deletion'), ('cellier', None, 'deletion'), ('estragon', 'béret', 'substitution'), ('instruments', 'tuit', 'substitution'), ('malédiction', 'joue', 'substitution')]}]
# Processing file:  4021_edugame2023_3c4c5fcf6345480cb955ca616a36edfa_0094b89100f14d28a479b2be7df89d38.wav
# ASR response:  [{'transcription': {'text': "piège femme secret se créer finit mille cerf cerf jardin précision dix c'est quoi ce mot dix lieux million débarquement", 'logit_score': -71.4586056689407, 'lm_score': -160.75617590785163, 'word_offsets': None}, 'alignment': [('piège', 'piège', 'match'), ('femme', 'femme', 'match'), ('secret', 'secret', 'match'), (None, 'se', 'insertion'), (None, 'créer', 'insertion'), ('finit', 'finit', 'match'), ('mille', 'mille', 'match'), (None, 'cerf', 'insertion'), ('cerf', 'cerf', 'match'), ('jardin', 'jardin', 'match'), ('précision', 'précision', 'match'), (None, 'dix', 'insertion'), (None, 'c', 'insertion'), (None, 'est', 'insertion'), (None, 'quoi', 'insertion'), (None, 'ce', 'insertion'), (None, 'mot', 'insertion'), ('dix', 'dix', 'match'), ('lieux', 'lieux', 'match'), ('million', 'million', 'match'), ('débarquement', 'débarquement', 'match')]}]
# Done with df_wav2vec2_xls_no_LM_beam

# %%
audio, sr = librosa.load('../Intervention_T1_data/recordings/deco_trials/FR_deco/FR_deco/3101_edugame2023_9a4621529c23405c8d2681287fed34a4_b0b4cf5f585b4888a333f7b73d48e62e.wav', sr=16000)
audio
# Out:
# array([ 1.9794676e-05,  3.3159624e-05,  2.9026451e-05, ...,
#        -1.2594093e-04, -5.1501807e-04, -6.2957359e-04], dtype=float32)

# %% [markdown]
# ### Brouillon

# %% [markdown]
# Notes:
#
# - I need to know the complexity level of reference texts so that I can evaluate the performance wrt to this criteria
# - Some audios are not processed by Whisperx, others not processed by IBM Watson, others not by both --> Empty response returned by ASR
# - Warning when loading wav2vec2 models disapear when running from huggingsound_env instead of asr

# %% [markdown]
# ##### Caller function (Todo: Update)

# %%
"""
Calls the segment service with the provided parameters.

Args:
  service_address (str): The address of the segment service.
  audio_file_path (str): The path to the audio file.
  reference_text (str): The reference text for the audio.
  language (str): The language of the audio and reference text.
  method (str): The method to be used by the segment service.
  model_ID_list (list): The list of model IDs to be used by the segment service.
  with_LM (bool): Whether to use the language model or not.

Returns:
  dict: The JSON response from the segment service.
"""
def call_segment_service( service_address, 
                          audio_file_path,
                          reference_text,
                          language,
                          method,
                          model_ID_list = None,
                          with_LM = False ):
                        
    audio_file_base64_string = base64.b64encode( open(audio_file_path, 'rb').read()).decode('ASCII')
    response = requests.post( service_address,
                              data = json.dumps( {
                                  "audio_file_base64_string":audio_file_base64_string,
                                  "reference_text":reference_text,
                                  "language":language,
                                  "method":method,
                                  "model_ID_list":model_ID_list,
                                  "with_LM":with_LM
                              } ),
                              headers = {"Content-Type": "application/json"}
                            )
    return response.json()

''' EXEMPLE OF USAGE
call_segment_service( 
            service_address = "http://localhost:8070/segment",  ### This is the service address, default on 8070 port.
            audio_file_path = audio_path,  ### path to the audio file
            reference_text = reference_text,
            language = language,   ### "it" for "italian", "fr" for "french", "de" for "german"
            method = "ibm-watson"  ### The name of the model, can be either "whisperx" or "ibm-watson"
        )
'''
# Out:
# ' EXEMPLE OF USAGE\ncall_segment_service( \n            service_address = "http://localhost:8070/segment",  ### This is the service address, default on 8070 port.\n            audio_file_path = audio_path,  ### path to the audio file\n            reference_text = reference_text,\n            language = language,   ### "it" for "italian", "fr" for "french", "de" for "german"\n            method = "ibm-watson"  ### The name of the model, can be either "whisperx" or "ibm-watson"\n        )\n'

# %%
"""
call_segment_service( 
            service_address = "http://localhost:8070/segment",  ### This is the service address, default on 8070 port.
            audio_file_path = recordings_filepaths[1],  ### path to the audio file
            reference_text = 'a b c',
            language = 'fr',   ### "it" for "italian", "fr" for "french", "de" for "german"
            method = "whisperx"  ### The name of the model, can be either "whisperx" or "ibm-watson"
  
        )

call_segment_service( 
            service_address = "http://localhost:8070/segment",  ### This is the service address, default on 8070 port.
            audio_file_path = recordings_filepaths[4],  ### path to the audio file
            reference_text = 'a b c',
            language = 'fr',   ### "it" for "italian", "fr" for "french", "de" for "german"
            method = "wav2vec2",  ### The name of the model, can be either "whisperx" or "ibm-watson"
            model_ID_list = ["jonatasgrosman/wav2vec2-xls-r-1b-french", 
                            "jonatasgrosman/wav2vec2-xls-r-1b-italian"],
            with_LM=False
        )

call_segment_service( 
            service_address = "http://localhost:8070/segment",  ### This is the service address, default on 8070 port.
            audio_file_path = recordings_filepaths[4],  ### path to the audio file
            reference_text = 'a b c',
            language = 'fr',   ### "it" for "italian", "fr" for "french", "de" for "german"
            method = "wav2vec2",  ### The name of the model, can be either "whisperx" or "ibm-watson"
            model_ID_list = ["jonatasgrosman/wav2vec2-xls-r-1b-french", 
                            "jonatasgrosman/wav2vec2-xls-r-1b-italian"],
            with_LM=True
        )
"""
# Out:
# '\ncall_segment_service( \n            service_address = "http://localhost:8070/segment",  ### This is the service address, default on 8070 port.\n            audio_file_path = recordings_filepaths[1],  ### path to the audio file\n            reference_text = \'a b c\',\n            language = \'fr\',   ### "it" for "italian", "fr" for "french", "de" for "german"\n            method = "whisperx"  ### The name of the model, can be either "whisperx" or "ibm-watson"\n  \n        )\n\ncall_segment_service( \n            service_address = "http://localhost:8070/segment",  ### This is the service address, default on 8070 port.\n            audio_file_path = recordings_filepaths[4],  ### path to the audio file\n            reference_text = \'a b c\',\n            language = \'fr\',   ### "it" for "italian", "fr" for "french", "de" for "german"\n            method = "wav2vec2",  ### The name of the model, can be either "whisperx" or "ibm-watson"\n            model_ID_list = ["jonatasgrosman/wav2vec2-xls-r-1b-french", \n                            "jonatasgrosman/wav2vec2-xls-r-1b-italian"],\n            with_LM=False\n        )\n\ncall_segment_service( \n            service_address = "http://localhost:8070/segment",  ### This is the service address, default on 8070 port.\n            audio_file_path = recordings_filepaths[4],  ### path to the audio file\n            reference_text = \'a b c\',\n            language = \'fr\',   ### "it" for "italian", "fr" for "french", "de" for "german"\n            method = "wav2vec2",  ### The name of the model, can be either "whisperx" or "ibm-watson"\n            model_ID_list = ["jonatasgrosman/wav2vec2-xls-r-1b-french", \n                            "jonatasgrosman/wav2vec2-xls-r-1b-italian"],\n            with_LM=True\n        )\n'
