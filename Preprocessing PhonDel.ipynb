# %%
import json
import pandas as pd
import os
import re
from collections import Counter
import librosa
import random
import IPython.display as ipd

# %% [markdown]
# # The paths

# %%
recordings_folder_path = r"../Intervention_T1_data/recordings/phondel_trials/FR_phonDel/FR_phonDel"
phon_del_trial_path = r"../Intervention_T1_data/ground_truth_transcribed/PhonDel/phonDel_test_ground_truth_ALL_T1_first_coder.csv"
path_filters = None

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# Load the dataframe containing the data

# %%
df = pd.read_csv(phon_del_trial_path)
print("Number of rows in df: ", len(df))
df.rename(columns={"Comments": "comments"}, inplace=True)
print("Columns in df: ", df.columns)

df
# Out:
# Number of rows in df:  11087
# Columns in df:  Index(['date_time', 'participant_id', 'session_id', 'trial_id', 'timePoint',
#        'language', 'session_form', 'phase', 'config_id', 'config', 'file_name',
#        'trial_answer', 'accuracy', 'notes', 'comments'],
#       dtype='object')
#               date_time    participant_id                        session_id  \
# 0      23.11.2023 09:26  3101_edugame2023  0e0417f6222649fe89cf6edb413e0423
# 1      23.11.2023 09:26  3101_edugame2023  0e0417f6222649fe89cf6edb413e0423
# 2      23.11.2023 09:24  3101_edugame2023  0e0417f6222649fe89cf6edb413e0423
# 3      23.11.2023 09:26  3101_edugame2023  0e0417f6222649fe89cf6edb413e0423
# 4      23.11.2023 09:24  3101_edugame2023  0e0417f6222649fe89cf6edb413e0423
# ...                 ...               ...                               ...
# 11082  20.11.2023 09:07   101_edugame2023                                 -
# 11083  20.11.2023 09:07   101_edugame2023                                 -
# 11084  20.11.2023 09:07   101_edugame2023                                 -
# 11085  20.11.2023 09:08   101_edugame2023                                 -
# 11086  20.11.2023 09:08   101_edugame2023                                 -
#
#                                trial_id timePoint language session_form  \
# 0      2249c5f2f75d4b089bee1f36e1a7aef2       PRE       fr            B
# 1      3eff2b8d9be54f24aaa5f0bf3ef81c50       PRE       fr            B
# 2      56dbefb3163a44beab895890b503600f       PRE       fr            B
# 3      5c6cef80aa54470caa4df67c9003aecc       PRE       fr            B
# 4      620b6b5984f14b0c90432d5a123e2106       PRE       fr            B
# ...                                 ...       ...      ...          ...
# 11082  bb53a95c95dc4ee0ad83b7443bb83848       PRE       It            C
# 11083  d9016ac30812441b958f1897eac9940e       PRE       It            C
# 11084  e9ce0cf1ae684d42add65da7b69beb65       PRE       It            C
# 11085  ec02fd447bc9419dba6b4422e0d40067       PRE       It            C
# 11086  ef60fb878d4944cda7f94f808931351c       PRE       It            C
#
#           phase           config_id   config  \
# 0      DELETION  phondel_B_pseudo_8   bromal
# 1      DELETION  phondel_B_pseudo_6   banéon
# 2      DELETION    phondel_B_word_2   cheval
# 3      DELETION  phondel_B_pseudo_7   polage
# 4      DELETION    phondel_B_word_3  fromage
# ...         ...                 ...      ...
# 11082  DELETION  phondel_A_pseudo_2    gleno
# 11083  DELETION    phondel_A_word_1    fiume
# 11084  DELETION  phondel_A_pseudo_1    piulo
# 11085  DELETION    phondel_A_word_5  sblocco
# 11086  DELETION  phondel_A_pseudo_5  sgrivia
#
#                                                file_name trial_answer  \
# 0      3101_edugame2023_1c148def3c254026adc7a7fdc3edc...      an.nage
# 1      3101_edugame2023_1c148def3c254026adc7a7fdc3edc...   {no audio}
# 2      3101_edugame2023_1c148def3c254026adc7a7fdc3edc...     ch euval
# 3      3101_edugame2023_1c148def3c254026adc7a7fdc3edc...        onage
# 4      3101_edugame2023_1c148def3c254026adc7a7fdc3edc...        omage
# ...                                                  ...          ...
# 11082  dummy_TEST_eb01e2e9529a4e90a9c7de1574d22425_bb...          NaN
# 11083  dummy_TEST_eb01e2e9529a4e90a9c7de1574d22425_d9...          NaN
# 11084  dummy_TEST_eb01e2e9529a4e90a9c7de1574d22425_e9...          NaN
# 11085  dummy_TEST_eb01e2e9529a4e90a9c7de1574d22425_ec...          NaN
# 11086  dummy_TEST_eb01e2e9529a4e90a9c7de1574d22425_ef...          NaN
#
#        accuracy                     notes comments
# 0           0.0                       NaN      NaN
# 1           NaN                       NaN      NaN
# 2           1.0  first_phoneme_repetition      NaN
# 3           1.0                       NaN      NaN
# 4           1.0                       NaN      NaN
# ...         ...                       ...      ...
# 11082       NaN                       NaN      NaN
# 11083       NaN                       NaN      NaN
# 11084       NaN                       NaN      NaN
# 11085       NaN                       NaN      NaN
# 11086       NaN                       NaN      NaN
#
# [11087 rows x 15 columns]

# %% [markdown]
# ## Modification of the database

# %% [markdown]
# 1) Drop some columns that are no relevant
#     - date_time, timePoint, trial_id
# 2) Change some column names to have more evocative names
#     - config --> reference_text
#     - trial_answer --> human_transcription
# 3) Add some column
#     - words_human_transcription: contains the transcription without the annotations
#     - human_alignment: contains the alignment between the clinician and asr transcription
#     - audio_length: duration of corresponding audio
#     - process_time: time ot took to the ASR to process the audio
#     - asr_response: response of the ASR
#     - asr_comparison: comparison between clinician and asr transcription (TP, TN, FP, FN)
# 4) Remove rows of the database without clinician annotations: 104 rows (all were marked as duplicate trial)
# 5) Keep only the files that are present in both the dataframe and in the recording folder and remove duplicate file (duplicate with respect to the file names)
# 6) Replace all ';' by a ' ' in the reference_text column for future alignment

# %%
def reformat_df(df, columns_drop, columns_rename, columns_add):

    df = df.drop(columns=columns_drop)
    df = df.rename(columns=columns_rename)
    for col in columns_add:
        df[col] = ""
    return df

# %%
def match_files_df_recordings(df, recordings_folder_path, path_filters=None):    
    recordings_filenames = []
    recordings_filepaths = []
    if path_filters is None:
        path_filters = ()

    # Get list of all audio filenames and paths in recordings folder whose paths contains all path filters
    for root, _, files in os.walk(recordings_folder_path):
        if all(filter in root for filter in path_filters):
            for file in files:
                if file.endswith(".wav"):
                    recordings_filenames.append(file)
                    recordings_filepaths.append(os.path.join(root, file))

    # Get the list of filenames in the json file
    df_filenames = df['filename'].tolist()

    # Get the list of filenames in the df file that are not in the recordings folder
    missing_recordings = list(set(df_filenames) - set(recordings_filenames))
    print(len(missing_recordings), " Files that are in the df but not in the recording folder (not processed): ", missing_recordings)

    # Get the list of filenames in the recordings folder that are not in the df
    extra_recordings = list(set(recordings_filenames) - set(df_filenames))
    print(len(extra_recordings), " Files that are in the recording folder but not in the df (not processed): ", extra_recordings)

    # Remove extra files from recordings_filepaths and missing files from df
    recordings_filepaths = [path for path in recordings_filepaths if os.path.basename(path) not in extra_recordings]
    df = df[~df['filename'].isin(missing_recordings)]

    # Remove the duplicate filenames from df and from recordings_filepaths
    print("Duplicate filenames in df (not processed): ", df[df['filename'].duplicated(keep=False)].sort_values('filename')['filename'].tolist())
    duplicate_list = [item for item, count in Counter(recordings_filepaths).items() if count > 1]
    print("Duplicate filenames in recordings folder (not processed): ", [item for item, count in Counter(recordings_filepaths).items() if count > 1])
    df = df.drop_duplicates(subset=['filename'], keep='first')
    recordings_filepaths = list(set(recordings_filepaths))

    # reset index of DataFrame
    df = df.reset_index(drop=True)

    # Verify number of files in DataFrame matches number of files in folder
    assert len(df) == len(recordings_filepaths), f"Number of files in DataFrame ({len(df)}) does not match number of files in folder ({len(recordings_filepaths)})"
    print("Number of files to be processed: ", len(df))

    return df, recordings_filepaths, recordings_filenames

# %%
### Change format of df to match the expected format ###
df = reformat_df(df = df, 
                    columns_drop = ['date_time','timePoint', 'trial_id'], 
                    columns_rename = {"config":"reference_text", "trial_answer":"human_transcription", "file_name": "filename"}, 
                    columns_add = ["words_human_transcription", "human_alignment", "asr_response", "asr_comparison", "audio_length", "process_time", "filepath", "accuracy_og"])
# Reorder the DataFrame columns
desired_order = ['participant_id', 'session_id', 'language', 'session_form', 'phase',
                 'config_id', 'filename', 'reference_text', 'words_human_transcription',
                 'human_transcription', 'accuracy', 'accuracy_og','notes', 'comments', 
                 'human_alignment', 'asr_response', 'asr_comparison', 'audio_length', 'process_time']
df = df[desired_order]


### Handle rows with NaN values in human_transcription column ###
print(df['human_transcription'].isnull().sum(), "rows with NaN values in human_transcription column and notes associated with these rows are", df[df['human_transcription'].isnull()]['notes'].unique(), "\n")
# Remove rows with NaN values in transcription column 
df = df.dropna(subset=['human_transcription']).reset_index(drop=True)


### Synchronize the DataFrame with the audio files by removing missing files and duplicates ###
df, recordings_filepaths, recordings_filenames = match_files_df_recordings(df = df, 
                                                                            recordings_folder_path = recordings_folder_path, 
                                                                            path_filters = path_filters)


# For each string in reference_text, replace the ; by a space for the alignment
df['reference_text'] = df['reference_text'].apply(lambda x: x.replace(";", " "))

# Add the filepath column to the DataFrame
df['filepath'] = [os.path.join(recordings_folder_path, filename) for filename in df['filename']]



# Save the updated df to a JSON file
df.to_json('dfs/phondel/Intervention_PhonDel_og_df.json', orient='records')

# Only keep rows in df_asr with language "fr" and reset index
df_asr_fr = df[df['language'] == 'fr'].reset_index(drop=True) #### FRENCH ONLY
# Out:
# 92 rows with NaN values in human_transcription column and notes associated with these rows are [nan]
#
dfdf.wav', '3745_edugame2023_1ca564663f4c407097cfbce117a5cc1f_03afb926279343d39470e6165e1194c0.wav', '3751_edugame2023_41de30b88c344b3c8dbba7a4d4c7febf_1d00a698b5a74370bb0c6807e58ae796.wav', '3167_edugame2023_a41d2a9d4fbd4047aa1c548d2b1b6f60_09844f7be6924aeca4d1dcb30349d4a6.wav', '4005_edugame2023_a80d9a4c316548ec936aefaa040ee5d6_3e9a91e7a3614db89f7e630481d11c4f.wav', '3124_edugame2023_8406bb32d04e43dfa8d64a760a815147_63bc56e5ed98471d9c561c0721f000de.wav', '4024_edugame2023_51cee7d687d740c9af97d4f80090de ...
# Duplicate filenames in df (not processed):  []
# Duplicate filenames in recordings folder (not processed):  []
# Number of files to be processed:  5506

# %%
# copy accuracy column to accuracy_og column
df['accuracy_og'] = df['accuracy']
# If accuracy row is nan replace it with 0.0
df['accuracy'] = df['accuracy'].apply(lambda x: 0.0 if pd.isna(x) else x)

# %%
# Check that the number of unique reference text and config_id match
assert len(df['reference_text'].unique()) == len(df['config_id'].unique()), "Number of unique reference text and config_id do not match"
print("Number of unique reference text and config_id match and is", len(df['reference_text'].unique()), "\n")

# Each config_id should have the same reference_text print them
for config_id in sorted(df['config_id'].unique()):
    print(config_id, df[df['config_id'] == config_id]['reference_text'].unique())
# Out:
# Number of unique reference text and config_id match and is 54
#
# phondel_A_pseudo_0 ['plique']
# phondel_A_pseudo_1 ['razin']
# phondel_A_pseudo_2 ['ganda']
# phondel_A_pseudo_3 ['glotu']
# phondel_A_pseudo_4 ['pladar']
# phondel_A_pseudo_5 ['spéréo']
# phondel_A_pseudo_6 ['gatine']
# phondel_A_pseudo_7 ['pobier']
# phondel_A_pseudo_8 ['trical']
# phondel_A_word_0 ['plume']
# phondel_A_word_1 ['râteau']
# phondel_A_word_2 ['chemin']
# phondel_A_word_3 ['frisson']
# phondel_A_word_4 ['canapé']
# phondel_A_word_5 ['station']
# phondel_A_word_6 ['glotte']
# phondel_A_word_7 ['solitude']
# phondel_A_word_8 ['camarade']
# phondel_B_pseudo_0 ['triffe']
# phondel_B_pseudo_1 ['mican']
# phondel_B_pseudo_2 ['condas']
# phondel_B_pseudo_3 ['glomo']
# phondel_B_pseudo_4 ['plabir']
# phondel_B_pseudo_5 ['spalio']
# phondel_B_pseudo_6 ['banéon']
# phondel_B_pseudo_7 ['polage']
# phondel_B_pseudo_8 ['bromal']
# phondel_B_word_0 ['plage']
# phondel_B_word_1 ['bateau']
# phondel_B_word_2 ['cheval']
# phondel_B_word_3 ['fromage']
# phondel_B_word_4 ['canari']
# phondel_B_word_5 ['spatule']
# phondel_B_word_6 ['gloire']
# phondel_B_word_7 ['sorcière']
# phondel_B_word_8 ['capitale']
# phondel_C_pseudo_0 ['troufe']
# phondel_C_pseudo_1 ['lajon']
# phondel_C_pseudo_2 ['pombin']
# phondel_C_pseudo_3 ['glomé']
# phondel_C_pseudo_4 ['plabète']
# phondel_C_pseudo_5 ['spudio']
# phondel_C_pseudo_6 ['panuge']
# phondel_C_pseudo_7 ['pogion']
# phondel_C_pseudo_8 ['protal']
# phondel_C_word_0 ['plaque']
# phondel_C_word_1 ['gâteau']
# phondel_C_word_2 ['chapeau']
# phondel_C_word_3 ['frigo']
# phondel_C_word_4 ['caméra']
# phondel_C_word_5 ['spirale']
# phondel_C_word_6 ['glaise']
# phondel_C_word_7 ['solution']
# phondel_C_word_8 ['caravane']

# %%
# Fill the audio_length column by adding the audio duration for each file in recordings_filepaths and get the total time
total_time = 0
for audio_path in recordings_filepaths:
    filename = os.path.basename(audio_path)
    if filename in df['filename'].values:
        audio_length = librosa.get_duration(path=audio_path)
        df.loc[df['filename'] == filename, 'audio_length'] = audio_length
        total_time += audio_length
print("\nTotal time of audio files:", total_time, "seconds =", total_time/60, "minutes")

# Print if a participant has multiple session_form values
print("\nNumber of participants with multiple session_form (A, B, C) values: ", len(df.groupby('participant_id')['session_form'].nunique()[df.groupby('participant_id')['session_form'].nunique() > 1]))

# Print the number of participants per language and trial
for lan in df['language'].unique():
    print("\n Total number of unique participants for each config_id in", lan)
    for config_id in df['config_id'].unique():
        filtered_df = df[(df['language'] == lan) & (df['config_id'] == config_id)]
        # print number of participants per config_id
        print(str(config_id) + " :  " + str(len(filtered_df['participant_id'].unique())))
    print(" \nTotal number of unique participants for each phase in", lan)
    for phase in df['phase'].unique():
        filtered_df = df[(df['language'] == lan) & (df['phase'].apply(lambda x: x.split("_")[0] in [phase]))]
        print(phase + " :  " + str(len(filtered_df['participant_id'].unique())) + " participants")
# Out:
# Total time of audio files: 21356.38984126983 seconds = 355.93983068783047 minutes
#
# Number of participants with multiple session_form (A, B, C) values:  0
#
#  Total number of unique participants for each config_id in fr
# phondel_B_pseudo_8 :  52
# phondel_B_pseudo_6 :  52
# phondel_B_word_2 :  52
# phondel_B_pseudo_7 :  52
# phondel_B_word_3 :  52
# phondel_B_pseudo_1 :  52
# phondel_B_word_8 :  52
# phondel_B_word_0 :  52
# phondel_B_pseudo_4 :  52
# phondel_B_word_5 :  52
# phondel_B_word_4 :  52
# phondel_B_word_6 :  52
# phondel_B_pseudo_3 :  52
# phondel_B_word_1 :  52
# phondel_B_pseudo_2 :  52
# phondel_B_pseudo_5 :  52
# phondel_B_pseudo_0 :  52
# phondel_B_word_7 :  52
# phondel_C_pseudo_5 :  52
# phondel_C_pseudo_7 :  52
# phondel_C_word_6 :  52
# phondel_C_word_1 :  52
# phondel_C_pseudo_3 :  52
# phondel_C_word_3 :  52
# phondel_C_word_4 :  52
# phondel_C_word_0 :  52
# phondel_C_word_8 :  52
# phondel_C_word_2 :  52
# phondel_C_pseudo_2 :  52
# phondel_C_pseudo_4 :  52
# phondel_C_pseudo_8 :  52
# phondel_C_word_5 :  52
# phondel_C_word_7 :  52
# phondel_C_pseudo_0 :  52
# phondel_C_pseudo_6 :  52
# phondel_C_pseudo_1 :  52
# phondel_A_pseudo_2 :  47
# phondel_A_word_3 :  47
# phondel_A_word_6 :  47
# phondel_A_word_7 :  46
# phondel_A_pseudo_3 :  47
# phondel_A_pseudo_6 :  46
# phondel_A_pseudo_7 :  46
# phondel_A_word_0 :  47
# phondel_A_word_5 :  47
# phondel_A_pseudo_4 :  47
# phondel_A_pseudo_5 :  47
# phondel_A_word_8 :  46
# phondel_A_word_4 :  47
# phondel_A_word_2 :  47
# phondel_A_word_1 :  47
# phondel_A_pseudo_8 :  46
# phondel_A_pseudo_0 :  47
# phondel_A_pseudo_1 :  47
#
# Total number of unique participants for each phase in fr
# DELETION :  151 participants
# REPETITION :  149 participants

# %% [markdown]
# ## Transcription Normalization

# %% [markdown]
# Get transcriptions without the annotations and write them in the words_human_transcription column. These will be fed to the ASR during training so they need to contain what was said without any comment or mark.
# - Remove the sounding out annotation '.' in the transcription : pa.pa --> papa
# - Remove the insertion annotation'{...}' in the transcription : pa{pu}pa --> papupa
# - Remove the comments {inaudible}, {comments}, {adult_support}, {adult_task}, {no audio}, {pause}, {cut recording}

# %% [markdown]
# Extra step: Remove all between brackets and parenthesis because we have transcriptions containing (indexes are those of df after cleaning):
#
# - [ :  putio [pytjo] , 267
# - [ :  o ofre [o] , 491
# - [ :  trofe [o] , 507
# - [ :  ofe [ɔ] , 603
# - ɔ :  ofe [ɔ] , 603
# - [ :  trofe [ɔ] , 626
# - ɔ :  trofe [ɔ] , 626
# - [ :  otrf [ɔ] , 1081
# - ɔ :  otrf [ɔ] , 1081
# - [ :  rofe [o] , 1171
# - [ :  rofr [o] , 1209
# - [ :  ofr [o] , 1239
# - [ :  offe [o] , 1364
# - [ :  offe [o] , 1378
# - ( :  atin(e)gue , 1552
# - [ :  offe [o] , 1589
# - :  in-nuge , 3401
# - ( :  s pudiome (o ouvert) , 4495

# %%
# Fill the words_human_transcription column with the human transcription with removed annotations
def remove_transcription_annotations(transcription):
    """
    Removes clinician annotations from a given transcription.
    Args:
        transcription (str): The input transcription string.
    Returns:
        str: The transcription string with annotations removed.
    """
    # If the letter before and after the "." is the same, only keep one letter and '.' ex: "a.ar" -> "ar"
    transcription = re.sub(r'(\w)\.(\1)', r'\2', transcription)
    transcription = transcription.replace(".", "")

    transcription = transcription.replace("{inaudible}", "")
    transcription = transcription.replace("{comments}", "")
    transcription = transcription.replace("{adult_support}", "")
    transcription = transcription.replace("{adult_task}", "")
    transcription = transcription.replace("{no audio}", "")
    transcription = transcription.replace("{pause}", "")
    transcription = transcription.replace("{cut recording}", "")

    transcription = transcription.replace("{", "")
    transcription = transcription.replace("}", "")

    # remove all between brackets and parenthesis
    transcription = re.sub(r'\[.*?\]', '', transcription)
    transcription = re.sub(r'\(.*?\)', '', transcription)

    return transcription

df['words_human_transcription'] = df['human_transcription'].apply(lambda x: remove_transcription_annotations(x))

# %% [markdown]
# The transcriptions in our dataset exhibit inconsistencies where the same word can be spelled differently across rows. To ensure consistent labeling for our finetuning task and accurate evaluation of the ASR performance, we need to normalize the spelling of correctly uttered words. To achieve this, we create a replacement dictionary that maps each variant spelling to a normalized spelling.
#
# To create the replacement dictionary, we iterate over each list of (pseudo)words. For each (pseudo)word in this list, we select only the rows where the clinician marked the word as correctly pronounced (where its value in the accuracy list is 2). We then check for discrepancies between the reference text and human transcription for these rows and add any identified discrepancies to our dictionary.

# %% [markdown]
# Here accuracy score of 2 will be marked as correct and the others as incorrect

# %%
list_filenames_1 = ['3701_edugame2023_3bc42b641b324df19b5e0062a69d96e1_b1b9010672944621a0e836947eadbb93.wav',
                    '4023_edugame2023_ae4c45a99b3249b9b7956b53eac1356f_d236a6ad182b4c42a49ec0e4991309fa.wav',

                  ]

list_filenames_0 = ['4021_edugame2023_2c00adcffb304ea29cf1e50f387b5f60_859df5b501104d388791e8556607fac0.wav',
                    '3712_edugame2023_e6c1c6fde35f47c3825b66bf237a377d_d69e204de61346ea971e1eb237918381.wav',
                    '3151_edugame2023_e491dd7fb2bf4f87be389ec9f010cee7_964a64f36b344ff9a0b734438af6716d.wav',
]

list_filenames_2 = ['3726_edugame2023_80869283edb446a196918178d6ecaa99_41750a185c9d4320ab6db2c402f75256.wav']

# search in the df for filenames in list_filenames_1, replace accuracy by 1.0
df.loc[df['filename'].isin(list_filenames_1), 'accuracy'] = 1.0
# search in the df for filenames in list_filenames_0, replace accuracy by 0.0
df.loc[df['filename'].isin(list_filenames_0), 'accuracy'] = 0.0

# for filename in list_filenames_2, replace words_human_transcription and human_transcription by the reference_text
df.loc[df['filename'].isin(list_filenames_2), 'words_human_transcription'] = df.loc[df['filename'].isin(list_filenames_2), 'reference_text']

# %%
# List of all config_ids ( = lists of (pseudo)words ) in the df
config_ids = df['config_id'].unique()
config_dfs = []
print("Number of unique config_id: ", len(config_ids))

for i in range(len(config_ids)): # index of the config_id to be processed 

    # Get all rows with the config_id we want to process
    df_config = df[df['config_id'] == config_ids[i]]
    # only keep when phase is REPETITION
    

    # Only keep rows where the accuracy is 2
    df_config = df_config.dropna(subset=['accuracy'])
    df_config.loc[:, 'accuracy'] = df_config['accuracy'].apply(lambda x: int(x))
    df_config = df_config[df_config['accuracy'].apply(lambda x: int(x) == 2)]

    df_config_del = df_config[df_config['phase'].apply(lambda x: x in 'DELETION')]
    df_config_del = df_config[df_config.apply(lambda x: (x['reference_text'][1:] not in x['words_human_transcription'].strip().split(" ")), axis=1)]
  
    # Show all rows where the word in the reference_text column is not contained in the string in the words_human_transcription column
    df_config = df_config[df_config['phase'].apply(lambda x: x in 'REPETITION')]
    df_config = df_config[df_config.apply(lambda x: (x['reference_text'] not in x['words_human_transcription'].strip().split(" ")), axis=1)]
    # if df_config is empty, continue to the next config_id
    if not df_config.empty:
        config_dfs.append(df_config)
        print('Index', i, ": Processed config_id: ", config_ids[i])
        print("Processed reference_text repetition:", df_config.iloc[0]['reference_text'])
        # for each row in df_config print the reference_text and words_human_transcription and the accuracy
        for index, row in df_config.iterrows():
            print(row['filename'])
            print(row['phase'], '/', row['words_human_transcription'], '/', row['accuracy'])
            #print(row['reference_text'][1:])
            #print(row['words_human_transcription'].strip().split(" "))
            #print(row['reference_text'][1:] not in row['words_human_transcription'].split(" "))
        print()
# Out:
# Number of unique config_id:  54
# Index 2 : Processed config_id:  phondel_B_word_2
# Processed reference_text repetition: cheval
# 3162_edugame2023_32793e0c589d4fa68ec56925c81f1c3f_1f751c30cd6849268d510f20e4f74564.wav
# REPETITION / cheuval / 2.0
# 3416_edugame2023_4a0b4d189b05483fa96185374eee5ffa_314ed60b4d074038a4bace9848c30679.wav
# REPETITION / cheuval / 2.0
# 3417_edugame2023_004738c4582e43c6ba3a3203dfbeb056_f6f15af87b4f491f84211b6dcd13f9bd.wav
# REPETITION / cheuval / 2.0
# 3420_edugame2023_9bfc27a89e1c4f2187008ecf0b9a826a_81640b5073d14e0a95e7de9b1259398d.wav
# REPETITION / cheuval / 2.0
# 3746_edugame2023_d1ce946d8f994e6587c94f7b6563b019_c6236011c31f4f42abbbd9aa800e8c5e.wav
# REPETITION / cheuval / 2.0
#
# Index 5 : Processed config_id:  phondel_B_pseudo_1
# Processed reference_text repetition: mican
# 3405_edugame2023_5b9989694d774a34a1eafaa610d7d0c2_b99960ab06fd44b191ac78ec7b069da7.wav
# REPETITION / ican / 2.0
#
# Index 13 : Processed config_id:  phondel_B_word_1
# Processed reference_text repetition: bateau
# 3417_edugame2023_004738c4582e43c6ba3a3203dfbeb056_f7cd868e49a84835a05205a9859151f1.wav
# REPETITION / beateau / 2.0
#
# Index 14 : Processed config_id:  phondel_B_pseudo_2
# Processed reference_text repetition: condas
# 3103_edugame2023_bd2e86a09e364acd8f5525df267664ed_52c943502b364acda52b17125c1ba6e4.wav
# REPETITION / conda / 2.0
# 3107_edugame2023_23b2f53e549547a78d98567a58665539_0458071d89174d1a974b5f9616a5918f.wav
# REPETITION / conda con con con conda conda / 2.0
# 3162_edugame2023_32793e0c589d4fa68ec56925c81f1c3f_80160a21ab85439b8ec0cd4988f9949b.wav
# REPETITION / conda / 2.0
# 3184_edugame2023_d424ed654fe54cde845b047fd81100fb_f255f34394194e419ba524c5a1285a3e.wav
# REPETITION / conda / 2.0
# 3416_edugame2023_4a0b4d189b05483fa96185374eee5ffa_645d0f915200413eb40441804ac8f34c.wav
# REPETITION / conda / 2.0
# 3417_edugame2023_004738c4582e43c6ba3a3203dfbeb056_af4521689f3544129720ef0c93852690.wav
# REPETITION / conda / 2.0
# 3420_edugame2023_9bfc27a89e1c4f2187008ecf0b9a826a_6f2cdc1106e54d78a9b91e4030c77e88.wav
# REPETITION / conda / 2.0
# 3421_edugame2023_149d415b5e314a18b55a9575b7fa0443_bc8eeabbe5954d0e878d4570408310ae.wav
# REPETITION / conda / 2.0
# 3726_edugame2023_80869283edb446a196918178d6ecaa99_ccbb4c84a0b64eedbbe581735006f899.wav
# REPETITION / conda / 2.0
# 3746_edugame2023_d1ce946d8f994e6587c94f7b6563b019_1ec7b69aaa4b4c34a8aadf5c542e6782.wav
# REPETITION / conda / 2.0
# 4005_edugame2023_e8ff509ede2c41f6967213e7fa748eba_a3337fa49aaf43bd92b060870fcea11f.wav
# 4021_edugame2023_2c00adcffb304ea29cf1e50f387b5f60_42848a73f692479b8be2560d802c3a0f.wav
# REPETITION / rateau / 2.0
# 4025_edugame2023_c2ff27793b1a4d689b79734ea8bfc177_9746e4a12b6a4c9ab8a40cf692667ada.wav
# REPETITION / rateau / 2.0

# %%
# List of all config_ids ( = lists of (pseudo)words ) in the df
config_ids = df['config_id'].unique()
config_dfs = []
print("Number of unique config_id: ", len(config_ids))

for i in range(len(config_ids)): # index of the config_id to be processed 

    # Get all rows with the config_id we want to process
    df_config = df[df['config_id'] == config_ids[i]]
    # only keep when phase is REPETITION
    

    # Only keep rows where the accuracy is 2
    df_config = df_config.dropna(subset=['accuracy'])
    df_config.loc[:, 'accuracy'] = df_config['accuracy'].apply(lambda x: int(x))
    df_config = df_config[df_config['accuracy'].apply(lambda x: int(x) == 2)]

    df_config = df_config[df_config['phase'].apply(lambda x: x in 'DELETION')]
    df_config = df_config[df_config.apply(lambda x: (x['reference_text'][1:] not in x['words_human_transcription'].strip().split(" ")), axis=1)]
  
    # Show all rows where the word in the reference_text column is not contained in the string in the words_human_transcription column
    # if df_config is empty, continue to the next config_id
    if not df_config.empty:
        config_dfs.append(df_config)
        print('Index', i, ": Processed config_id: ", config_ids[i])
        print("Processed reference_text repetition:", df_config.iloc[0]['reference_text'])
        print("Processed reference_text deletion:", df_config.iloc[0]['reference_text'][1:])
        # for each row in df_config print the reference_text and words_human_transcription and the accuracy
        for index, row in df_config.iterrows():
            print(row['filename'])
            print(row['phase'], '/', row['words_human_transcription'], '/', row['accuracy'])
            #print(row['reference_text'][1:])
            #print(row['words_human_transcription'].strip().split(" "))
            #print(row['reference_text'][1:] not in row['words_human_transcription'].split(" "))
        print()
# Out:
# Number of unique config_id:  54
# Index 2 : Processed config_id:  phondel_B_word_2
# Processed reference_text repetition: cheval
# Processed reference_text deletion: heval
# 3111_edugame2023_4c44aca8f5384bcdbe71dde1dfcef2c7_2f55c7851d1d4dbe997c20bcd6e2fec3.wav
# DELETION / euval / 2.0
# 3118_edugame2023_3c686e53fdb9487db3ddc5df86592967_9aded2d1b5c243909791bacb01d5eb03.wav
# DELETION / euval / 2.0
# 3124_edugame2023_9ad8272b040541ab84acc2bcbd54aa4a_455ad58d67d744fb9e9b5fd87cd30ed7.wav
# DELETION / eu euval / 2.0
# 3127_edugame2023_4959a495407c466bb9a26cf24c129cea_543330a86386477ab45f0f738df5185e.wav
# DELETION / euval / 2.0
# 3132_edugame2023_bbc5159ce61148a49da08f5f6f2afb60_9892d9de65714f8195e8d31c7f0b5654.wav
# DELETION / euval / 2.0
# 3147_edugame2023_9ea3ec00205249e8a6f410525222dbab_29451355d2b6444095d801b82fd1c4ca.wav
# DELETION / euval / 2.0
# 3149_edugame2023_bd00b4024cdf4ee491269af5b74cd509_7e5fc21492d1429393c33cec3244cec6.wav
# DELETION / euval / 2.0
# 3152_edugame2023_277d765afc3e44d69a8a7b7da04766ab_fd84ab3d658344f4a2531d0ac286115c.wav
# DELETION / euval / 2.0
# 4006_edugame2023_8caad9aeffc34a04a8d1b7c6b86e83d3_b9b16c7240de47de9859940dd759c382.wav
# DELETION / euval / 2.0
# 4011_edugame2023_a5f82108080b42c896807e20d4aa71e3_988c59343e3e44229e7ffb21fbf070b2.wav
# DELETION / euval / 2.0
# 4012_edugame2023_deeeebd97d2a4783be169ea9ae27984f_1f9d215689cd42e7a1a4ab96901d3af7.wav
# DELETION / euval / 2.0
# 4015_edugame2023_2d16a65e9d214798b5c1462d59c6099f_7ff5fc62ad0b42978317e68d6be55cb8.wav
# DELETION / euval / 2.0
# 4020_edugame2023_ee790e3143fc4606b40b0a6f6edd2c54_702079ac79e54bee9a8f3a5bb9a3589e.wav
# DELETION / euval / 2.0
#
# Index 11 : Processed config_id:  phondel_B_word_6
# Processed reference_text repetition: gloire
# Processed reference_text deletion: loire
# 3122_edugame2023_d0eb9c3e21ff4b4585c170f1fc535ea6_83964faebb494a32a029f76c3d74d15c.wav
# DELETION / loiregl / 2.0
#
# Index 14 : Processed config_id:  phondel_B_pseudo_2
# Processed reference_text repetition: condas
# Processed reference_text deletion: ondas
# 3107_edugame2023_9236361a711a469f92143f61ffcd77f7_01b48e842b0d4d379ad3f66041d85af1.wav
# DELETION / conda onda / 2.0
# 3111_edugame2023_4c44aca8f5384bcdbe71dde1dfcef2c7_843b56a45e2844c1b607317e09e22f42.wav
# DELETION / onda / 2.0
# 3113_edugame2023_33b8a1b952c242538340c287998d8258_13e803424b644e09aa7859a6bf250581.wav
# DELETION / onda / 2.0
# 3118_edugame2023_3c686e53fdb9487db3ddc5df86592967_0a690e69ef4d4901a521c016baaf8a6d.wav
# DELETION / onda / 2.0
# 3122_edugame2023_d0eb9c3e21ff4b4585c170f1fc535ea6_af981461b1fe4825bda0a26252f7092f.wav
# DELETION / conda onda / 2.0
# 3124_edugame2023_9ad8272b040541ab84acc2bcbd54aa4a_9dfecf8e1433407495d3eaaf8b306d34.wav
# DELETION / onda / 2.0
# 3127_edugame2023_4959a495407c466bb9a26cf24c129cea_75dc9d37e0d943cabf435f09c58e5efd.wav
# DELETION / onda / 2.0
# 3132_edugame2023_bbc5159ce61148a49da08f5f6f2afb60_0e5d44da06d64a86a2c89a0962c08194.wav
# DELETION / onda / 2.0
# 3149_edugame2023_bd00b4024cdf4ee491269af5b74cd509_1bcb73691664444e929626a163f4cbfc.wav
# DELETION / onda / 2.0
# 3152_edugame2023_277d765afc3e44d69a8a7b7da04766ab_7a2df42bd98c435cab869e999e20c057.wav
# DELETION / onda / 2.0
# 3158_edugame2023_25534b1327f2489b97fdcde80f3f035f_2617984c670744fda1c82e28fa0e80c6.wav
# DELETION / onda / 2.0
# 3162_edugame2023_132ff79bde9b4daea9943a875224a09f_79e7a347699d442fa63367294221c721.wav
# DELETION / onda / 2.0
# 3164_edugame2023_77aff5056fe54a848aca63db1b7e2535_e69040bd17894e16968bc27960d304ca.wav
# DELETION / onda / 2.0
# DELETION / apeau / 2.0
# 4009_edugame2023_c9a21a75e93e48f6a6840224e6a6de46_863cc368aa4443f595fa4f8e6cbf6d7e.wav
# DELETION / apeau / 2.0
# 4010_edugame2023_4635f9c4aa9b49af80aebe89d605bc03_0a38afee56634659b86efc57b7e04e66.wav
# DELETION / apeau / 2.0
# 4018_edugame2023_40221a685e6b4ff984ef273e63f4cfbc_2e1df794b1784c85b6e25179edfadb2d.wav
# DELETION / apeau / 2.0
# 4023_edugame2023_ae4c45a99b3249b9b7956b53eac1356f_23811868091b4e64946a96f7476e56bc.wav
# DELETION / apeau / 2.0
# 4024_edugame2023_ab9f5ffb9b3847babcbe5bbb9706d3f5_084f226fb763497290fbe78668c9b302.wav
# DELETION / apeau / 2.0
# 4026_edugame2023_a92ff17a973747db847356f72b9d2c0e_1505fcec21754166a92a7ffb021406a2.wav
# DELETION / apeau apeau / 2.0
#
# Index 30 : Processed config_id:  phondel_C_pseudo_8
# Processed reference_text repetition: protal
# Processed reference_text deletion: rotal
# 3740_edugame2023_1dbfc8ca008d43cbaf16a0495c15174d_29da326d5a484e259fe2c159ea77c49c.wav
# DELETION / trotal / 2.0
#
# Index 32 : Processed config_id:  phondel_C_word_7
# Processed reference_text repetition: solution
# Processed reference_text deletion: olution
# 3102_edugame2023_752a81c0c3b2479f94c31f988fc4c402_dd8b1552097a40cb979888a17c0a2ae2.wav
# DELETION / olussion / 2.0
# 3108_edugame2023_48d599b0a4a3453ba73be2d79c73feac_7cb689fee81e4c279eee15b301561251.wav
# DELETION / olussion / 2.0
# 3108_edugame2023_83b9f2cdeb0c493f9a65263bc611cb74_0fcc8916d21e4413900329af30f6e6d9.wav
# DELETION / olussion / 2.0
# 3112_edugame2023_8476ba81a0e34ad09984e2920695751a_65a082ba47d64fc9a14a72ec3f14b518.wav
# DELETION / so olussion / 2.0
# 3126_edugame2023_0ff76c46b10e4be98661cb1a62d8a1cc_065252c0814741ba910566f8adec3d6f.wav
# DELETION / olussion / 2.0
# 3136_edugame2023_6eea39c3bf094841ae0d110c91568763_67ad117f8b7d442cb1df5e363b5ef992.wav
# DELETION / olussion / 2.0
# 3138_edugame2023_0226c99509854d4c95f9b02131865479_8514e151e0864d408f2d6791b9a53b19.wav
# DELETION / olussion / 2.0
# 3142_edugame2023_e99dbc6b3fea4e2aa8622a327e7159e3_de6a743453b040e0ae95dc110a46fd4a.wav
# DELETION / olussion / 2.0
# 3154_edugame2023_658f833bbc524abba95e04df6c1682ef_315bc7c3dab64c69a9a09037b769d791.wav
# DELETION / solussion so olussion / 2.0
# 3157_edugame2023_89570d463df64eacaedfffd18cd38da3_e2d572558ad14b59a8a95bbf961b34ab.wav
# DELETION / olussion / 2.0
# 3161_edugame2023_ad090f8a86144d349f49f654013e2f68_40555c8991c24265bfc82572b0d03c40.wav
# DELETION / olussion / 2.0
# 3169_edugame2023_17c11a8f620540b288a6e414ab3922a3_49bb067953e44484948f01d0628bf31e.wav
# 4024_edugame2023_ab9f5ffb9b3847babcbe5bbb9706d3f5_20077af447104f53a8a32ac3b671ae1b.wav
# DELETION / olussion / 2.0
# 4026_edugame2023_a92ff17a973747db847356f72b9d2c0e_9b17becbc972469cb61d287e940158bb.wav
# DELETION / olussion olussion / 2.0
#
# Index 44 : Processed config_id:  phondel_A_word_5
# Processed reference_text repetition: station
# Processed reference_text deletion: tation
# 3105_edugame2023_879b650d76d74d8081ba631b080c0f44_7bacbcdd56ca4361ae4c764d05685bef.wav
# DELETION / tassion / 2.0
# 3123_edugame2023_4d04085ec34443f684682a61486242c7_e677d79bf56e465c801612b83c3952ea.wav
# DELETION / tassion / 2.0
# 3155_edugame2023_651a06fa7c824643bb1308727e97ca6f_e0c0fd8d84a9491389d4ef83b268e90d.wav
# DELETION / stassion sta tassion / 2.0
# 3170_edugame2023_9fd374ddfbe7490787b168e36969185f_6fda6a1fa83e4c9a9d7fc7c36452b397.wav
# DELETION / tassion / 2.0
# 3411_edugame2023_f733f8e330ae435db0859b5e60106526_9b2e22e9b0d84b6fbedffe41131f7004.wav
# DELETION / tassion / 2.0
# 3723_edugame2023_75c2d1514d4a4b57ac079984da27bc5a_2cd4018feb5f4441ba4408e76c4a462b.wav
# DELETION / tassion / 2.0
# 3728_edugame2023_d59ee4335c354c14aa90dae953634591_5cd2b98a08f54119b8a620b4de3ba159.wav
# DELETION / tassion / 2.0
# 3730_edugame2023_277f27946f394717b3e711c37b603210_ce061a771d154b3d9ec1d53c02eea197.wav
# DELETION / stassion a tassion / 2.0
# 3744_edugame2023_f20135e4a97a458397a97f1e17199488_2867b0b7921543f49d15381c4618adfc.wav
# DELETION / tassion / 2.0
# 4007_edugame2023_0f424e6914914cc4803df4335a6f1d9c_40df3b7a8200419f916be657687790d4.wav
# DELETION / stassion stassion tassion tassion / 2.0
# 4008_edugame2023_189649781e3549749538428b4a9ddbb4_dfc6a2637ba345ae8ac568252de3d761.wav
# DELETION / tassion / 2.0
# 4013_edugame2023_462381628cbe433f86c6c3e4308a3ec3_887c0d1350424f9a9a18680a35ec85a6.wav
# DELETION / sta stassion tassion tassion tassion / 2.0
#
# Index 49 : Processed config_id:  phondel_A_word_2
# Processed reference_text repetition: chemin
# Processed reference_text deletion: hemin
# 3106_edugame2023_36a83598ce0e45e693ad3957b90975c5_d5c9899fca1e46b48d69b94d60c05040.wav
# DELETION / cheumin eumin / 2.0
# 3110_edugame2023_eccf5f8ad31043e29dbc88fda81b7be3_e904073c6a554c1eb80a42287fe7f71f.wav
# DELETION / eumin / 2.0
# 3131_edugame2023_a5eed4e2dec245d784cde66b282c0793_22c3073c821c4a27b65cd3b8f93ad562.wav
# DELETION / eumin / 2.0
# 3135_edugame2023_f2ac294453464f2b88dfedd1ea1bd025_bea0a0558ce94c7a820d88c60408f627.wav
# DELETION / eumin / 2.0
# 3143_edugame2023_aecc3187edd548f0bd63779565f52938_ddc4dfdd7558450797184362f8f2005e.wav
# DELETION / eumin / 2.0
# 3135_edugame2023_f2ac294453464f2b88dfedd1ea1bd025_f762429b1cd543718b48d65ee635b93d.wav
# DELETION / ateau / 2.0
# 3155_edugame2023_651a06fa7c824643bb1308727e97ca6f_a60d793342584b28861da8839c56c155.wav
# DELETION / ateau ateau / 2.0
# 3168_edugame2023_5a929fbe5add4889a9ab8e727d2fd074_50ab07f9f01f42eda885d20c77aaa6f1.wav
# DELETION / ateau / 2.0
# 3170_edugame2023_9fd374ddfbe7490787b168e36969185f_93f29c60a74441c7b051f23d1d20ee80.wav
# DELETION / ateau / 2.0
# 3411_edugame2023_f733f8e330ae435db0859b5e60106526_96206ed34a5848dc8cd07ba13dcb0731.wav
# DELETION / ateau / 2.0
# 3723_edugame2023_75c2d1514d4a4b57ac079984da27bc5a_031422e564d9422ba626a44c946ad05f.wav
# DELETION / ateau / 2.0
# 3725_edugame2023_12866c47c30b473a91d6d39246f71ea3_50a65e20de094cde81e986d08749b1f6.wav
# DELETION / ateau / 2.0
# 3728_edugame2023_d59ee4335c354c14aa90dae953634591_67d3004458224d59b49364095b2f8e66.wav
# DELETION / ateau / 2.0
# 3730_edugame2023_277f27946f394717b3e711c37b603210_1b45cb47616f4cc1985340a23b86c277.wav
# DELETION / ateau / 2.0
# 4007_edugame2023_0f424e6914914cc4803df4335a6f1d9c_b90c763d9ba543b9b1c9a909d9f95ff5.wav
# DELETION / ateau / 2.0
# 4008_edugame2023_189649781e3549749538428b4a9ddbb4_a1584d013aac4fbda44573dd425519b0.wav
# DELETION / ateau / 2.0
# 4013_edugame2023_462381628cbe433f86c6c3e4308a3ec3_6456f6c43c7e49aba8531a9d321fe302.wav
# DELETION / ra ateau / 2.0
#
# Index 52 : Processed config_id:  phondel_A_pseudo_0
# Processed reference_text repetition: plique
# Processed reference_text deletion: lique
# 3170_edugame2023_9fd374ddfbe7490787b168e36969185f_82a270ab92d449afb318d126ddc2d471.wav
# DELETION / i like / 2.0

# %%
# List of all config_ids ( = lists of (pseudo)words ) in the df
config_ids = df['config_id'].unique()
config_dfs = []
print("Number of unique config_id: ", len(config_ids))

for i in range(len(config_ids)): # index of the config_id to be processed 

    # Get all rows with the config_id we want to process
    df_config = df[df['config_id'] == config_ids[i]]
    # only keep when phase is REPETITION
    

    # Only keep rows where the accuracy is not 2
    df_config = df_config.dropna(subset=['accuracy'])
    df_config.loc[:, 'accuracy'] = df_config['accuracy'].apply(lambda x: int(x))
    df_config = df_config[df_config['accuracy'].apply(lambda x: int(x) != 2)]

    # Show all rows where the word in the reference_text column is not contained in the string in the words_human_transcription column
    df_config = df_config[df_config['phase'].apply(lambda x: x in 'REPETITION')]
    df_config = df_config[df_config.apply(lambda x: (x['reference_text'] in x['words_human_transcription'].split(" ")), axis=1)]
    # if df_config is empty, continue to the next config_id
    if not df_config.empty:
        config_dfs.append(df_config)
        print('Index', i, ": Processed config_id: ", config_ids[i])
        print("Processed reference_text repetition:", df_config.iloc[0]['reference_text'])
        # for each row in df_config print the reference_text and words_human_transcription and the accuracy
        for index, row in df_config.iterrows():
            #print(row['filename'])
            print(row['phase'], '/', row['words_human_transcription'], '/', row['accuracy'])
            #print(row['reference_text'][1:])
            #print(row['words_human_transcription'].strip().split(" "))
            #print(row['reference_text'][1:] not in row['words_human_transcription'].split(" "))
        print()
# Out:
# Number of unique config_id:  54
# Index 0 : Processed config_id:  phondel_B_pseudo_8
# Processed reference_text repetition: bromal
# REPETITION / bromal omage / 1.0
#
# Index 1 : Processed config_id:  phondel_B_pseudo_6
# Processed reference_text repetition: banéon
# REPETITION / banéon banéon ba anéon / 1.0
#
# Index 5 : Processed config_id:  phondel_B_pseudo_1
# Processed reference_text repetition: mican
# REPETITION / mican ican / 1.0
#
# Index 6 : Processed config_id:  phondel_B_word_8
# Processed reference_text repetition: capitale
# REPETITION / capitale apitale / 1.0
# REPETITION / capitale talcapi / 1.0
#
# Index 10 : Processed config_id:  phondel_B_word_4
# Processed reference_text repetition: canari
# REPETITION / canari nari / 0.0
#
# Index 11 : Processed config_id:  phondel_B_word_6
# Processed reference_text repetition: gloire
# REPETITION / gloire gloire oire / 1.0
# REPETITION / gloire gl gl g g gl loire loire / 1.0
# REPETITION / gloire loire loire loire / 1.0
#
# Index 12 : Processed config_id:  phondel_B_pseudo_3
# Processed reference_text repetition: glomo
# REPETITION / glomo lomo / 1.0
# REPETITION / glomo go lomo / 1.0
#
# Index 13 : Processed config_id:  phondel_B_word_1
# Processed reference_text repetition: bateau
# REPETITION / bateau ateau / 0.0
#
# Index 18 : Processed config_id:  phondel_C_pseudo_5
# Processed reference_text repetition: spudio
# REPETITION / spudio spudio diospu / 1.0
# REPETITION / spudio diospu / 0.0
#
# Index 20 : Processed config_id:  phondel_C_word_6
# Processed reference_text repetition: glaise
# REPETITION / glaise lèz / 1.0
#
# Index 22 : Processed config_id:  phondel_C_pseudo_3
# Processed reference_text repetition: glomé
# REPETITION / glomé / 1.0
# REPETITION / glomé émogl / 1.0
# REPETITION / glomé mlogué / 0.0
#
# Index 25 : Processed config_id:  phondel_C_word_0
# Processed reference_text repetition: plaque
# REPETITION / plaque akle / 1.0
# REPETITION / p plaque plaple paple / 1.0
#
# Index 29 : Processed config_id:  phondel_C_pseudo_4
# Processed reference_text repetition: plabète
# REPETITION / plabète pètebla pètebla / 1.0
#
# Index 38 : Processed config_id:  phondel_A_word_6
# Processed reference_text repetition: glotte
# REPETITION / glotte glotte glotte lotte / 1.0
# REPETITION / glotte lotte / 1.0
#
# Index 39 : Processed config_id:  phondel_A_word_7
# Processed reference_text repetition: solitude
# REPETITION / solitude tudesolide / 1.0
# REPETITION /  solitude solitude olitude / 1.0
#
# Index 40 : Processed config_id:  phondel_A_pseudo_3
# Processed reference_text repetition: glotu
# REPETITION / glotu tu tuglo / 1.0
#
# Index 41 : Processed config_id:  phondel_A_pseudo_6
# Processed reference_text repetition: gatine
# REPETITION / gatine itine / 1.0
# REPETITION / gatine atine / 1.0
#
# Index 42 : Processed config_id:  phondel_A_pseudo_7
# Processed reference_text repetition: pobier
# REPETITION / pobier biépo / 1.0
#
# Index 43 : Processed config_id:  phondel_A_word_0
# Processed reference_text repetition: plume
# REPETITION / plu plume lume lume lume / 1.0
#
# Index 45 : Processed config_id:  phondel_A_pseudo_4
# Processed reference_text repetition: pladar
# REPETITION / pladar adar / 1.0
# REPETITION / pladar adar / 1.0
# REPETITION / pladar ladar / 1.0
#
# Index 46 : Processed config_id:  phondel_A_pseudo_5
# Processed reference_text repetition: spéréo
# REPETITION / éréo spéréo s sp péré péréo / 1.0
#
# Index 47 : Processed config_id:  phondel_A_word_8
# Processed reference_text repetition: camarade
# REPETITION / ama camarade ca amarade / 1.0
# REPETITION / an amarade camarade camarade amarade / 1.0
# REPETITION / camarade ra mat e / 1.0
# REPETITION / camarade amarade / 1.0
# REPETITION / camarade / 1.0
#
# Index 48 : Processed config_id:  phondel_A_word_4
# Processed reference_text repetition: canapé
# REPETITION / cana can canapé anapé / 1.0
# REPETITION / canapé pénaca / 1.0
# REPETITION / canapé pécan pécan / 1.0
# REPETITION / canapé anapé / 1.0
# REPETITION / canapé pécana / 1.0
#
# Index 49 : Processed config_id:  phondel_A_word_2
# Processed reference_text repetition: chemin
# REPETITION / ch chemin minch / 1.0
#
# Index 51 : Processed config_id:  phondel_A_pseudo_8
# Processed reference_text repetition: trical
# REPETITION / trical trit t trical tri ical / 0.0
# REPETITION / trical caltri / 1.0
# REPETITION / trical tri rical / 1.0
#
# Index 53 : Processed config_id:  phondel_A_pseudo_1
# Processed reference_text repetition: razin
# REPETITION / razin azin / 1.0

# %%
# List of all config_ids ( = lists of (pseudo)words ) in the df
config_ids = df['config_id'].unique()
config_dfs = []
print("Number of unique config_id: ", len(config_ids))

for i in range(len(config_ids)): # index of the config_id to be processed 

    # Get all rows with the config_id we want to process
    df_config = df[df['config_id'] == config_ids[i]]
    # only keep when phase is REPETITION
    

    # Only keep rows where the accuracy is 2
    df_config = df_config.dropna(subset=['accuracy'])
    df_config.loc[:, 'accuracy'] = df_config['accuracy'].apply(lambda x: int(x))
    df_config = df_config[df_config['accuracy'].apply(lambda x: int(x) != 2)]

    df_config = df_config[df_config['phase'].apply(lambda x: x in 'DELETION')]
    df_config = df_config[df_config.apply(lambda x: (x['reference_text'][1:] in x['words_human_transcription'].strip().split(" ")), axis=1)]
  
    # Show all rows where the word in the reference_text column is not contained in the string in the words_human_transcription column
    # if df_config is empty, continue to the next config_id
    if not df_config.empty:
        config_dfs.append(df_config)
        print('Index', i, ": Processed config_id: ", config_ids[i])
        print("Processed reference_text repetition:", df_config.iloc[0]['reference_text'])
        print("Processed reference_text deletion:", df_config.iloc[0]['reference_text'][1:])
        # for each row in df_config print the reference_text and words_human_transcription and the accuracy
        for index, row in df_config.iterrows():
            print(row['filename'])
            print(row['phase'], '/', row['words_human_transcription'], '/', row['accuracy'])
        print()
# Out:
# Number of unique config_id:  54
# Index 1 : Processed config_id:  phondel_B_pseudo_6
# Processed reference_text repetition: banéon
# Processed reference_text deletion: anéon
# 3181_edugame2023_9305eed61e8d4b3d99b88c83f0bc2703_fc3fd7e7c0bf43139de9abb0d0cc8ab7.wav
# DELETION / b anéon / 1.0
#
# Index 3 : Processed config_id:  phondel_B_pseudo_7
# Processed reference_text repetition: polage
# Processed reference_text deletion: olage
# 3752_edugame2023_e62014d710fd4ea1a22b11e9e2023959_746befef51d94ac8861de5f07334df4f.wav
# DELETION / p olage / 1.0
#
# Index 4 : Processed config_id:  phondel_B_word_3
# Processed reference_text repetition: fromage
# Processed reference_text deletion: romage
# 3103_edugame2023_4cdb2baccd9341c89a743a854bf7a985_f87714d2c5714a488ad64141a21c4e85.wav
# DELETION / f romage / 1.0
# 3156_edugame2023_5b68689254634805b9b823b0b2d5fd6b_565725b57a7f43478ab414ff456afaf3.wav
# DELETION / fro romage  / 0.0
#
# Index 7 : Processed config_id:  phondel_B_word_0
# Processed reference_text repetition: plage
# Processed reference_text deletion: lage
# 3147_edugame2023_9ea3ec00205249e8a6f410525222dbab_dee71ecd48804f03a7c19d1320c78eec.wav
# DELETION / p lage / 1.0
# 4015_edugame2023_2d16a65e9d214798b5c1462d59c6099f_de447fa38c7548bbb321c60279af7178.wav
# DELETION / plage p lage / 1.0
#
# Index 8 : Processed config_id:  phondel_B_pseudo_4
# Processed reference_text repetition: plabir
# Processed reference_text deletion: labir
# 4011_edugame2023_a5f82108080b42c896807e20d4aa71e3_c05fa44bcad74ad58610729db1fec683.wav
# DELETION / bir p labir labir / 1.0
#
# Index 9 : Processed config_id:  phondel_B_word_5
# Processed reference_text repetition: spatule
# Processed reference_text deletion: patule
# 3173_edugame2023_abeb5b56e3b24decb719f2597f1f7730_2648b1aa3dd94bca9eee97f1a78a5cff.wav
# DELETION / s patule / 1.0
# 3405_edugame2023_b3a8499f073847709efcc48c9be96a39_5f82ee1dfa1548aaae5a10d603185e5b.wav
# DELETION / patule atule / 1.0
# 3746_edugame2023_9c6c024f62c642eeac6cd30ba3e984c6_2762d13ef10146bc97f89b1eae97e3f6.wav
# DELETION / s patule / 1.0
# 3750_edugame2023_d1a07d39b93e427780077e12104f8459_5d67706fa02f44f7b375105215645ce1.wav
# DELETION / s p patule / 1.0
# 4015_edugame2023_2d16a65e9d214798b5c1462d59c6099f_b7af83fc11574c739f40e51707eb936d.wav
# DELETION / s patule / 1.0
#
# Index 10 : Processed config_id:  phondel_B_word_4
# Processed reference_text repetition: canari
# Processed reference_text deletion: anari
# 3147_edugame2023_9ea3ec00205249e8a6f410525222dbab_109b00b46b1e48f0851d4d3b186fe591.wav
# DELETION / k anari / 1.0
# 3416_edugame2023_307278761fcd4a93b20e84dbc6b24b4d_a0ba3d1a98d34bec837dd0cf8d9e5aa3.wav
# DELETION / k anari / 1.0
#
# Index 11 : Processed config_id:  phondel_B_word_6
# Processed reference_text repetition: gloire
# Processed reference_text deletion: loire
# 3147_edugame2023_9ea3ec00205249e8a6f410525222dbab_bb3e800a5d934648ae0c5a4cdc16bc50.wav
# DELETION / g loire loire / 1.0
# 3739_edugame2023_abb8b7e14d9c469c99aaba74a2b6f150_df18fd5c45874b1c8fad709b149f7383.wav
# DELETION / loire / 1.0
#
# Index 13 : Processed config_id:  phondel_B_word_1
# Processed reference_text repetition: bateau
# Processed reference_text deletion: ateau
# 3147_edugame2023_9ea3ec00205249e8a6f410525222dbab_a91f328b78874fd1a0323aa6b167b6a8.wav
# DELETION / b ateau / 1.0
#
# Index 15 : Processed config_id:  phondel_B_pseudo_5
# Processed reference_text repetition: spalio
# Processed reference_text deletion: palio
# 3147_edugame2023_9ea3ec00205249e8a6f410525222dbab_9c98c9c6c9454d55b26ba0923e071e15.wav
# DELETION / s s palio palio / 1.0
# 3149_edugame2023_bd00b4024cdf4ee491269af5b74cd509_7417176d386e4fc6aa1cd794aa77bbca.wav
# DELETION / s s palio / 1.0
# 3181_edugame2023_9305eed61e8d4b3d99b88c83f0bc2703_8d85a98578584ca3857ff68a64255fd6.wav
# DELETION / spa s palio / 1.0
# 3185_edugame2023_4fff2db413da4db3a8b3d023e3fc0582_86e99614f0ba45d3bde9f511ea7e7105.wav
# DELETION / palio sp aspio / 0.0
#
# Index 16 : Processed config_id:  phondel_B_pseudo_0
# Processed reference_text repetition: triffe
# Processed reference_text deletion: riffe
# 3758_edugame2023_a6c42d31cff94ec49a96e29b74ca6d2c_a16dedb8e5f644f998ccd0b3ea02128e.wav
# DELETION / riffe criffe / 0.0
#
# Index 17 : Processed config_id:  phondel_B_word_7
# Processed reference_text repetition: sorcière
# Processed reference_text deletion: orcière
# 3173_edugame2023_abeb5b56e3b24decb719f2597f1f7730_a647c7a8314449bfa1ba5f60d3969af4.wav
# DELETION / s orcière / 1.0
#
# Index 18 : Processed config_id:  phondel_C_pseudo_5
# Processed reference_text repetition: spudio
# Processed reference_text deletion: pudio
# 3126_edugame2023_0ff76c46b10e4be98661cb1a62d8a1cc_bf6f9b9564f34a39a0e4e88a4832012b.wav
# DELETION / s pudio / 1.0
# 3151_edugame2023_cb4478fd35ac41c3bbb85318030dfce4_e5c2ab1d8ca24faf9f20f0fcf8060a4b.wav
# DELETION / s p s pudio / 1.0
# 3154_edugame2023_658f833bbc524abba95e04df6c1682ef_5b57b41a994b4ff3ad3b8313522a56ac.wav
# DELETION / spudio spudio spudio spudio s pudio pudio / 1.0
# 3187_edugame2023_ceb307486d2d4d47a939360f116fd041_06651198992b48b086818642d48967a3.wav
# DELETION / s pudio / 1.0
# 3711_edugame2023_cc5e12725ef44174b6065f252ba1270a_9836e870ea144213a73d1991d6dab19a.wav
# DELETION / s pudio / 1.0
# 3729_edugame2023_f23b4e5419eb4ab29837383cd79955ef_9ff41af64b384f00a84ffa98b107516a.wav
# DELETION / s pudio / 1.0
# 3740_edugame2023_1dbfc8ca008d43cbaf16a0495c15174d_8168f3dec41b4726b6c3fb92616dae85.wav
# DELETION / s pudio / 1.0
# 4019_edugame2023_e1f98d08c6ef4118ba61b137cab281fa_f5c97be5fc84434ea63be2779006ad3b.wav
# DELETION / pudio spudo / 0.0
#
# Index 19 : Processed config_id:  phondel_C_pseudo_7
# Processed reference_text repetition: pogion
# Processed reference_text deletion: ogion
# 4010_edugame2023_4635f9c4aa9b49af80aebe89d605bc03_7ad83cf148724699a8f9137f230c0708.wav
# DELETION / p ogion / 1.0
#
# Index 22 : Processed config_id:  phondel_C_pseudo_3
# Processed reference_text repetition: glomé
# Processed reference_text deletion: lomé
# 3133_edugame2023_b5dd0f96733146809be98565f2bc0380_18aa3da7bf444bc88f97fe2faca9c5a2.wav
# DELETION / gl l lomé / 0.0
#
# Index 23 : Processed config_id:  phondel_C_word_3
# Processed reference_text repetition: frigo
# Processed reference_text deletion: rigo
# 3104_edugame2023_6d940721e89c4d45840fcb307338e2da_c79215f270e04029b1aa1d1c9c830eda.wav
# DELETION / f rigo / 1.0
# 3740_edugame2023_1dbfc8ca008d43cbaf16a0495c15174d_24f2a0b39c5c454992dde9e4d003d517.wav
# DELETION / i f rigo / 1.0
#
# Index 24 : Processed config_id:  phondel_C_word_4
# Processed reference_text repetition: caméra
# Processed reference_text deletion: améra
# 3133_edugame2023_b5dd0f96733146809be98565f2bc0380_c27e80737ba1445680b070e8e30c157d.wav
# DELETION / k améra / 1.0
#
# Index 25 : Processed config_id:  phondel_C_word_0
# Processed reference_text repetition: plaque
# Processed reference_text deletion: laque
# 3161_edugame2023_ad090f8a86144d349f49f654013e2f68_b82fdd33869e4c8ab9a6a2b7c2eb9b76.wav
# DELETION / p laque laque / 1.0
#
# Index 26 : Processed config_id:  phondel_C_word_8
# Processed reference_text repetition: caravane
# Processed reference_text deletion: aravane
# 3171_edugame2023_e26189f95b6a450bbd9accf84274ace2_a072fcbf7c5c484ebea8b75065e2cede.wav
# DELETION / k aravane / 1.0
# 3740_edugame2023_1dbfc8ca008d43cbaf16a0495c15174d_235ca4fb637841fb9f20544734bea65d.wav
# DELETION / k aravane / 1.0
#
# Index 27 : Processed config_id:  phondel_C_word_2
# Processed reference_text repetition: chapeau
# Processed reference_text deletion: hapeau
# 3701_edugame2023_3bc42b641b324df19b5e0062a69d96e1_d4eb5f32380447f7b7a15f04afd957f7.wav
# DELETION / hapeau hapeau / 1.0
#
# Index 30 : Processed config_id:  phondel_C_pseudo_8
# Processed reference_text repetition: protal
# Processed reference_text deletion: rotal
# 3404_edugame2023_1454b0ad390544459b44a009c1f168f3_859df830caa94dfe9c0eeb1af7e88353.wav
# DELETION / p rotal / 1.0
#
# Index 31 : Processed config_id:  phondel_C_word_5
# Processed reference_text repetition: spirale
# Processed reference_text deletion: pirale
# 3179_edugame2023_0248d73a6eb44697ba6be46f147ec6c8_1d3a1d720d4d42e291ead3926b92bcf7.wav
# DELETION / s pirale / 1.0
# 3187_edugame2023_ceb307486d2d4d47a939360f116fd041_6aef9b8d07e94924ada4b43d96f96b31.wav
# DELETION / s pirale / 1.0
# 3729_edugame2023_f23b4e5419eb4ab29837383cd79955ef_36c4fb8ba2c6441885543c15ff9c8d1c.wav
# DELETION / s pirale / 1.0
#
# Index 34 : Processed config_id:  phondel_C_pseudo_6
# Processed reference_text repetition: panuge
# Processed reference_text deletion: anuge
# 3157_edugame2023_89570d463df64eacaedfffd18cd38da3_75b26b81c1ad444a8ecf18bcbb89e12d.wav
# DELETION / anuge unuge / 1.0
#
# Index 36 : Processed config_id:  phondel_A_pseudo_2
# Processed reference_text repetition: ganda
# Processed reference_text deletion: anda
# 3123_edugame2023_4d04085ec34443f684682a61486242c7_299ce2040b974c209b58c24b555abc2a.wav
# DELETION / g anda / 1.0
#
# Index 38 : Processed config_id:  phondel_A_word_6
# Processed reference_text repetition: glotte
# Processed reference_text deletion: lotte
# 3177_edugame2023_efb4ebb2419f4a6d99d9118df4dc557c_6dced2b78f834348bd5a88772d9429b3.wav
# DELETION / glotte lotte glotte glotte lotte glotte glotte te / 0.0
#
# Index 39 : Processed config_id:  phondel_A_word_7
# Processed reference_text repetition: solitude
# Processed reference_text deletion: olitude
# 3170_edugame2023_9fd374ddfbe7490787b168e36969185f_e3f46fc7ba8d4aaa8f9024e8b2fd68e0.wav
# DELETION / s olitude / 1.0
#
# Index 40 : Processed config_id:  phondel_A_pseudo_3
# Processed reference_text repetition: glotu
# Processed reference_text deletion: lotu
# 3134_edugame2023_04764b0ef4a64110ab95a6b4eecba9ff_32fbba19df5948e0a4dd2d09592441e4.wav
# DELETION / g lotu / 1.0
#
# Index 41 : Processed config_id:  phondel_A_pseudo_6
# Processed reference_text repetition: gatine
# Processed reference_text deletion: atine
# 4013_edugame2023_462381628cbe433f86c6c3e4308a3ec3_c5ea863d23af4790a52fac2705494fa4.wav
# DELETION / g atine / 1.0
#
# Index 42 : Processed config_id:  phondel_A_pseudo_7
# Processed reference_text repetition: pobier
# Processed reference_text deletion: obier
# 3110_edugame2023_eccf5f8ad31043e29dbc88fda81b7be3_a25c1614a57b4aaf9f7883dbfc929197.wav
# DELETION / p obier / 1.0
#
# Index 43 : Processed config_id:  phondel_A_word_0
# Processed reference_text repetition: plume
# Processed reference_text deletion: lume
# 4017_edugame2023_b0ca2722c10c427099dd30bda0d8b8ae_3c77fd424d3a4f479a569771bfad854b.wav
# DELETION / p p p lume / 1.0
#
# Index 45 : Processed config_id:  phondel_A_pseudo_4
# Processed reference_text repetition: pladar
# Processed reference_text deletion: ladar
# 3725_edugame2023_12866c47c30b473a91d6d39246f71ea3_758e36e8d5c74ef6a56fdd06b8b96da7.wav
# DELETION / p ladar / 1.0
#
# Index 46 : Processed config_id:  phondel_A_pseudo_5
# Processed reference_text repetition: spéréo
# Processed reference_text deletion: péréo
# 3182_edugame2023_dff95d6e8025483e89e9ac2d42300574_bb47d840293e4277ac6a8b0fa4dbb408.wav
# DELETION / péréo é ssé o ésséo / 0.0
# 3408_edugame2023_23f680099d5d48788a2ad1cd0623198f_734b79286fc64dc99b0a93eec5449154.wav
# DELETION / s péréo / 1.0
# 3713_edugame2023_047e950372c44345b5b002de8a385fe2_fc65f5d38f304df4b8f054f8c5c9470f.wav
# DELETION / péréo épéro / 0.0
# 3714_edugame2023_de835e04a9f7458a9c6a8e122f73710b_55eea4b8da7a41618377ab1bececed7f.wav
# DELETION / s péréo s pérédo pérédo pérédo pérédo / 0.0
#
# Index 47 : Processed config_id:  phondel_A_word_8
# Processed reference_text repetition: camarade
# Processed reference_text deletion: amarade
# 4021_edugame2023_86ef158b212d4d0f9c4f81d36a4d33b2_733e39dcd59f406bbc86d4d12944dd85.wav
# DELETION / camarade k amarade / 1.0
#
# Index 48 : Processed config_id:  phondel_A_word_4
# Processed reference_text repetition: canapé
# Processed reference_text deletion: anapé
# 3106_edugame2023_36a83598ce0e45e693ad3957b90975c5_33e1541fc8c64755bd070eedb380aa8c.wav
# DELETION / c anapé / 1.0
#
# Index 52 : Processed config_id:  phondel_A_pseudo_0
# Processed reference_text repetition: plique
# Processed reference_text deletion: lique
# 3110_edugame2023_eccf5f8ad31043e29dbc88fda81b7be3_50c96ef8f1f346a7ba1c6179d6091b7f.wav
# DELETION / p lique / 1.0
#
# Index 53 : Processed config_id:  phondel_A_pseudo_1
# Processed reference_text repetition: razin
# Processed reference_text deletion: azin
# 3723_edugame2023_75c2d1514d4a4b57ac079984da27bc5a_63bfedc01d7444d68086a857db769b70.wav
# DELETION / r azin / 1.0
# 4017_edugame2023_b0ca2722c10c427099dd30bda0d8b8ae_b55cbce757204ca1a2dbe825755f47d3.wav
# DELETION / r azin / 1.0

# %% [markdown]
# -  reference_text repetition: mican
# - REPETITION / ican / 2.0
# - 3405_edugame2023_5b9989694d774a34a1eafaa610d7d0c2_b99960ab06fd44b191ac78ec7b069da7.wav

# %% [markdown]
# -  reference_text repetition: bateau
# - REPETITION / beateau / 2.0
# - 3417_edugame2023_004738c4582e43c6ba3a3203dfbeb056_f7cd868e49a84835a05205a9859151f1.wav

# %% [markdown]
# -  reference_text repetition: protal
# - Processed reference_text deletion: rotal
# - DELETION / trotal / 2.0
# - 3740_edugame2023_1dbfc8ca008d43cbaf16a0495c15174d_29da326d5a484e259fe2c159ea77c49c.wav

# %%
replacements = {
    'lèz': 'laise',
    'glèz': 'glaise',
    'conda': 'condas',
    'onda': 'ondas',
    'solussion': 'solution',
    'olussion': 'olution',
    'stassion': 'station',
    'tassion': 'tation',
    'like': 'lique',
}

# cheval -> euval index 0
# chemin -> eumin index 11

# %%
df_config = config_dfs[13] # 1 6 8 9  
print("Processed reference_text repetition:", df_config.iloc[0]['reference_text'])
print("Processed reference_text deletion:", df_config.iloc[0]['reference_text'][1:])
df_config
# Out:
# Processed reference_text repetition: pogion
# Processed reference_text deletion: ogion
#         participant_id                        session_id language  \
# 4958  4010_edugame2023  81ddcf87851c495f83c0bbdd75d09189       fr
#
#      session_form     phase           config_id  \
# 4958            C  DELETION  phondel_C_pseudo_7
#
#                                                filename reference_text  \
# 4958  4010_edugame2023_4635f9c4aa9b49af80aebe89d605b...         pogion
#
#      words_human_transcription human_transcription  accuracy  accuracy_og  \
# 4958                   p ogion             p ogion       1.0          1.0
#
#                        notes comments human_alignment asr_response  \
# 4958  first_phoneme_deletion      NaN
#
#      asr_comparison audio_length process_time  \
# 4958                    2.763175
#
#                                                filepath
# 4958  ../Intervention_T1_data/recordings/phondel_tri...

# %%
# Create a copy of the df


# Add a space before and after each key and value in the replacements dictionary to avoid replacing parts of words
# For example "re" in "arbre" will not replaced by "reux"
replacements = {f" {k} ": f" {v} " for k, v in replacements.items()}
# Add a space before each sentence in words_human_transcription
df['words_human_transcription'] = df['words_human_transcription'].apply(lambda x: f" {x} ")
df_not_normalized = df.copy()

# Replace the keys with the values in the replacements dictionary
for k, v in replacements.items():
    df['words_human_transcription'] = df['words_human_transcription'].str.replace(k, v)

# %% [markdown]
# Code to check all the transcriptions containing a given word:

# %%
word = 'like'
df_row = df_not_normalized.loc[df_not_normalized['words_human_transcription'].str.contains(' '+word+' ')]
df_row
# Out:
#         participant_id                        session_id language  \
# 2175  3170_edugame2023  79d1e001114a463a825e425ec54beeae       fr
#
#      session_form     phase           config_id  \
# 2175            A  DELETION  phondel_A_pseudo_0
#
#                                                filename reference_text  \
# 2175  3170_edugame2023_9fd374ddfbe7490787b168e369691...         plique
#
#      words_human_transcription human_transcription  accuracy  accuracy_og  \
# 2175                   i like               i like       2.0          2.0
#
#              notes comments human_alignment asr_response asr_comparison  \
# 2175  sounding_out      NaN
#
#      audio_length process_time  \
# 2175          8.0
#
#                                                filepath
# 2175  ../Intervention_T1_data/recordings/phondel_tri...

# %% [markdown]
# After the normalization of the spelling:

# %%
word = 'like'
df_row = df.loc[df['words_human_transcription'].str.contains(' '+word+' ')]
df_row
# Out:
# Empty DataFrame
# Columns: [participant_id, session_id, language, session_form, phase, config_id, filename, reference_text, words_human_transcription, human_transcription, accuracy, accuracy_og, notes, comments, human_alignment, asr_response, asr_comparison, audio_length, process_time, filepath]
# Index: []

# %% [markdown]
# #### Some explanation required here
# Some mistach between accuracy score and word transcribed seen for the following (there might be more those are the ones that I have noticed)

# %% [markdown]
# - row 796: diege but tiege but accurcy is 2

# %% [markdown]
# Code to check the mismatch for a given row:

# %%
for index in [3879, 1597, 5339,3601, 5265, 3401]:
    print('Filename : ' + df.loc[index]['filename'])
    print('Reference Text : ' + df.loc[index]['reference_text'])
    print('Human Transcription : ' +  df.loc[index]['human_transcription'])
    print('Words Human Transcription : ' + df.loc[index]['words_human_transcription'])
    print('Accuracy : ', df.loc[index]['accuracy'])
    print()
# Out:
# Filename : 3726_edugame2023_80869283edb446a196918178d6ecaa99_41750a185c9d4320ab6db2c402f75256.wav
# Reference Text : capitale
# Human Transcription : capiptale
# Words Human Transcription :  capitale
# Accuracy :  2.0
#
# Filename : 3151_edugame2023_e491dd7fb2bf4f87be389ec9f010cee7_964a64f36b344ff9a0b734438af6716d.wav
# Reference Text : spirale
# Human Transcription : spira.l
# Words Human Transcription :  spiral
# Accuracy :  0.0
#
# Filename : 4023_edugame2023_ae4c45a99b3249b9b7956b53eac1356f_d236a6ad182b4c42a49ec0e4991309fa.wav
# Reference Text : spirale
# Human Transcription : irale
# Words Human Transcription :  irale
# Accuracy :  1.0
#
# Filename : 3712_edugame2023_e6c1c6fde35f47c3825b66bf237a377d_d69e204de61346ea971e1eb237918381.wav
# Reference Text : lajon
# Human Transcription : ch apeau apeau
# Words Human Transcription :  ch apeau apeau
# Accuracy :  0.0
#
# Filename : 4021_edugame2023_2c00adcffb304ea29cf1e50f387b5f60_859df5b501104d388791e8556607fac0.wav
# Reference Text : solitude
# Human Transcription : solutide
# Words Human Transcription :  solutide
# Accuracy :  0.0
#
# Filename : 3701_edugame2023_3bc42b641b324df19b5e0062a69d96e1_b1b9010672944621a0e836947eadbb93.wav
# Reference Text : panuge
# Human Transcription : in-nuge
# Words Human Transcription :  in-nuge
# Accuracy :  1.0

# %% [markdown]
# ## Data Cleaning

# %%
df
# Out:
#         participant_id                        session_id language  \
# 0     3101_edugame2023  0e0417f6222649fe89cf6edb413e0423       fr
# 1     3101_edugame2023  0e0417f6222649fe89cf6edb413e0423       fr
# 2     3101_edugame2023  0e0417f6222649fe89cf6edb413e0423       fr
# 3     3101_edugame2023  0e0417f6222649fe89cf6edb413e0423       fr
# 4     3101_edugame2023  0e0417f6222649fe89cf6edb413e0423       fr
# ...                ...                               ...      ...
# 5501  3739_edugame2023                               NaN       fr
# 5502  3739_edugame2023                               NaN       fr
# 5503  3739_edugame2023                               NaN       fr
# 5504  3739_edugame2023                               NaN       fr
# 5505  3739_edugame2023                               NaN       fr
#
#      session_form       phase           config_id  \
# 0               B    DELETION  phondel_B_pseudo_8
# 1               B    DELETION  phondel_B_pseudo_6
# 2               B    DELETION    phondel_B_word_2
# 3               B    DELETION  phondel_B_pseudo_7
# 4               B    DELETION    phondel_B_word_3
# ...           ...         ...                 ...
# 5501            B  REPETITION    phondel_B_word_7
# 5502            B  REPETITION  phondel_B_pseudo_6
# 5503            B  REPETITION    phondel_B_word_8
# 5504            B  REPETITION  phondel_B_pseudo_7
# 5505            B  REPETITION  phondel_B_pseudo_8
#
#                                                filename reference_text  \
# 0     3101_edugame2023_1c148def3c254026adc7a7fdc3edc...         bromal
# 1     3101_edugame2023_1c148def3c254026adc7a7fdc3edc...         banéon
# 2     3101_edugame2023_1c148def3c254026adc7a7fdc3edc...         cheval
# 3     3101_edugame2023_1c148def3c254026adc7a7fdc3edc...         polage
# 4     3101_edugame2023_1c148def3c254026adc7a7fdc3edc...        fromage
# ...                                                 ...            ...
# 5501  3739_edugame2023_726b0378066f47358975f01c3230e...       sorcière
# 5502  3739_edugame2023_726b0378066f47358975f01c3230e...         banéon
# 5503  3739_edugame2023_726b0378066f47358975f01c3230e...       capitale
# 5504  3739_edugame2023_726b0378066f47358975f01c3230e...         polage
# 5505  3739_edugame2023_726b0378066f47358975f01c3230e...         bromal
#
#      words_human_transcription human_transcription  accuracy  accuracy_og  \
# 0                       anage              an.nage       0.0          0.0
# 1                                       {no audio}       0.0          NaN
# 2                    ch euval             ch euval       1.0          1.0
# 3                       onage                onage       1.0          1.0
# 4                       omage                omage       1.0          1.0
# ...                        ...                 ...       ...          ...
# 5501                 sorcière             sorcière       2.0          2.0
# 5502                   banéon               banéon       2.0          2.0
# 5503                 capitale             capitale       2.0          2.0
# 5504                                   {inaudible}       0.0          NaN
# 5505                                   {inaudible}       0.0          NaN
#
#                          notes  \
# 0                          NaN
# 1                          NaN
# 2     first_phoneme_repetition
# 3                          NaN
# 4                          NaN
# ...                        ...
# 5501                       NaN
# 5502                       NaN
# 5503                       NaN
# 5504                       NaN
# 5505                       NaN
#
#                                                comments human_alignment  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...             ...
# 5501                                                NaN
# 5502  someone is talking loudly behind the voice of ...
# 5503                                          whispered
# 5504                                                NaN
# 5505                                                NaN
#
#      asr_response asr_comparison audio_length process_time  \
# 0                                    4.144762
# 1                                   12.027937
# 2                                    8.573968
# 3                                    1.544127
# 4                                    9.102222
# ...           ...            ...          ...          ...
# 5501                                    3.712
# 5502                                      3.2
# 5503                                     2.24
# 5504                                    1.984
# 5505                                    2.432
#
#                                                filepath
# 0     ../Intervention_T1_data/recordings/phondel_tri...
# 1     ../Intervention_T1_data/recordings/phondel_tri...
# 2     ../Intervention_T1_data/recordings/phondel_tri...
# 3     ../Intervention_T1_data/recordings/phondel_tri...
# 4     ../Intervention_T1_data/recordings/phondel_tri...
# ...                                                 ...
# 5501  ../Intervention_T1_data/recordings/phondel_tri...
# 5502  ../Intervention_T1_data/recordings/phondel_tri...
# 5503  ../Intervention_T1_data/recordings/phondel_tri...
# 5504  ../Intervention_T1_data/recordings/phondel_tri...
# 5505  ../Intervention_T1_data/recordings/phondel_tri...
#
# [5506 rows x 20 columns]

# %%
df_not_cleaned = df.copy()
print("Total number of rows in df  before removal: ", len(df_not_cleaned))

df = df[~df['notes'].str.strip().isin(["duplicate_trial"])]
df.to_json('dfs/phondel/Intervention_PhonDel_df.json')
print("Total number of rows in df after removal: ", len(df))

# Remove rows where accuracy is nan
df = df.dropna(subset=['accuracy'])
print("Total number of rows in df after removal: ", len(df))

# create a df with all the rows that have been removed for training
df = df[~df['notes'].str.strip().isin(["not_doing_task", "inaudible", "not_doing_task inaudible", "duplicate_trial"])]
df = df[~df['human_transcription'].str.contains("adult")]
df = df[~df['words_human_transcription'].str.strip().isin([""])]
print("Total number of rows in df after removal: ", len(df))
# Print the rows with the notes "not_doing_task", "inaudible" or "not_doing_task inaudible"
# df_not_cleaned[df_not_cleaned['notes'].str.strip().isin(["not_doing_task", "inaudible", "not_doing_task inaudible"])]

# Save the updated df to a JSON file
print("Type of accuracy column of first row: ", type(df.loc[0]['accuracy']))
df.to_json('dfs/phondel/train/Intervention_PhonDel_df.json')

df = pd.read_json('dfs/phondel/Intervention_PhonDel_df.json')
print("Type of accuracy column of first row: ", type(df.loc[0]['accuracy']))
# Out:
# Total number of rows in df  before removal:  5506
# Total number of rows in df after removal:  5506
# Total number of rows in df after removal:  5506
# Total number of rows in df after removal:  4698
# Type of accuracy column of first row:  <class 'numpy.float64'>
# Type of accuracy column of first row:  <class 'numpy.int64'>
